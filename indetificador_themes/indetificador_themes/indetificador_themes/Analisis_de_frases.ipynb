# %%
# !pip install rake-nltk
# !python -m spacy download es_core_news_md
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: rake-nltk in /usr/local/lib/python3.8/dist-packages (1.0.6)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /usr/local/lib/python3.8/dist-packages (from rake-nltk) (3.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (4.64.1)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (1.2.0)
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-01-30 12:56:40.409886: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting es-core-news-md==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_md-3.4.0/es_core_news_md-3.4.0-py3-none-any.whl (42.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 MB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from es-core-news-md==3.4.0) (3.4.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (2.0.8)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (1.0.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (4.64.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (2.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (0.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (21.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (1.10.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (2.4.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (2.25.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (2.11.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (6.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (3.0.8)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (1.21.6)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (0.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (57.4.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (8.1.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (1.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (3.0.11)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (4.4.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (1.24.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->es-core-news-md==3.4.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_md')
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.8/dist-packages (4.25.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.12.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from textblob import TextBlob
import statistics
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import string
import spacy
from spacy.lang.es.examples import sentences 
from spacy.lang.es.stop_words import STOP_WORDS
from sklearn.decomposition import LatentDirichletAllocation
from transformers import BertTokenizer, BertForSequenceClassification
import torch
from textblob import TextBlob
import re
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
nltk.download('stopwords');
nltk.download('wordnet');
nltk.download('punkt');
nltk.download('omw-1.4');
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
df = pd.read_csv('data_clean_145 - data_clean_145.csv')
df2 = pd.read_csv('data_clean_desde_indice_1078_hasta_el_final_csv.csv')
df2.rename(columns = {'CAMPA��':'CAMPAÑA'}, inplace = True)
df2.rename(columns = {'Valido':'Valida'}, inplace = True)
df2.drop(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'Unnamed: 0.1.1.1','Unnamed: 0.1.1.1.1', 'Unnamed: 0.1.1.1.1.1', 'level_0', 'index','Unnamed: 0.1.1.1.1.1.1'], inplace=True, axis=1)

# %%
df2.columns
# Out:
# Index(['ID_MOPC', 'IDMOROSO', 'IDCLIENTE', 'OPERADOR', 'CAMPAÑA',
#        'IDGRABACION', 'TIPO_DISCADOR', 'FECHA', 'ID', 'IDLLAMADA', 'ESTADO',
#        'SUBESTADO', 'F_INICIO', 'ANI_TELEFONO', 'GRABACION_DEP', 'TIPO', 'CRM',
#        'BASE', 'LOG', 'DIRECCION', 'IDOPERADOR', 'AGENDAMIENTO_ESTADO', 'anos',
#        'mes', 'transcripcion_limpia', 'transcripcion', 'Contestador',
#        'Valida'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['ID_MOPC', 'IDMOROSO', 'IDCLIENTE', 'OPERADOR', 'CAMPAÑA',
#        'IDGRABACION', 'TIPO_DISCADOR', 'FECHA', 'ID', 'IDLLAMADA', 'ESTADO',
#        'SUBESTADO', 'F_INICIO', 'ANI_TELEFONO', 'GRABACION_DEP', 'TIPO', 'CRM',
#        'BASE', 'LOG', 'DIRECCION', 'IDOPERADOR', 'AGENDAMIENTO_ESTADO', 'anos',
#        'mes', 'transcripcion_limpia', 'Contestador', 'transcripcion',
#        'Valida'],
#       dtype='object')

# %%
len(df), len(df2) #1870
# Out:
# (2157, 1871)

# %%
for n in range(len(df)):
  for i in range(len(df2)):
    if df.IDGRABACION[n] == df2.IDGRABACION[i]:
      df2.transcripcion[i] = df.transcripcion[n]
# Out:
# <ipython-input-8-ff9db34c7d37>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.transcripcion[i] = df.transcripcion[n]

# %%
df2.transcripcion[134]
# Out:
# "['[00:00.000 --> 00:01.000]  Hola.', '[00:01.000 --> 00:04.000]  Sí, buen día, la servista Yagelín.', '[00:04.000 --> 00:07.000]  No, no se encuentra ella.', '[00:07.000 --> 00:12.000]  Eh, señor, la está llamando a la señora María Rosa de la Agencia M.O.P.C.', '[00:12.000 --> 00:16.000]  por la dedo del Banco Francesco. ¿Usted habló el otro día?', '[00:16.000 --> 00:18.000]  Sí.', '[00:18.000 --> 00:21.000]  ¿Usted le pudo avisar a ella?', '[00:21.000 --> 00:26.000]  Sí, pero me dice ella que ella está sin trabajo y que no puede hacer nada.', '[00:26.000 --> 00:30.000]  Pero tiene que comunicarse igual.', '[00:30.000 --> 00:31.000]  ¿Cómo?', '[00:31.000 --> 00:35.000]  Pero igual tiene que comunicarse mandando un whatsapp y yo las hago por teléfono.', '[00:35.000 --> 00:39.000]  Si estás sin trabajo, ¿tiene un número de teléfono para darme?', '[00:39.000 --> 00:41.000]  ¿Cómo, cómo?', '[00:41.000 --> 00:47.000]  ¿No tiene un número de teléfono donde yo puedo hablar con ella?', '[00:47.000 --> 00:51.000]  No, ella ahora no tenía porque, mira, se quedó hasta sin teléfono.', '[00:51.000 --> 00:56.000]  Así que no, le robaron el teléfono y no pudo comprar más.', '[00:56.000 --> 00:58.000]  Se lo robaron de la mano.', '[00:58.000 --> 01:00.000]  Sí.', '[01:00.000 --> 01:04.000]  ¿Y pero si usted tuviera que llamarla, no tiene ningún número para poderla ubicar?', '[01:04.000 --> 01:14.000]  No, sí, yo a veces cuando la encuentro o algo, o viene para mi casa cuando puede y hablamos.', '[01:14.000 --> 01:23.000]  ¿Por qué hay posibilidades que le puedo apagar por mes para hacer un plan de pagos en cuotas fijas?', '[01:23.000 --> 01:29.000]  Sí, pero no sé de cuánto es la deuda.', '[01:29.000 --> 01:35.000]  Bueno, usted puede hacerse cargo de la deuda, a ver, aguardemos segundito, no es una deuda muy alta,', '[01:35.000 --> 01:39.000]  por eso es una lástima que pierda la posibilidad de solucionarlo.', '[01:39.000 --> 01:41.000]  Sí.', '[01:41.000 --> 01:46.000]  A ver, aguardeme. ¿Cómo es su nombre, señora?', '[01:46.000 --> 01:48.000]  Graciela.', '[01:48.000 --> 01:51.000]  Señora Graciela, aguardeme.', '[01:51.000 --> 01:53.000]  Sí.', '[01:53.000 --> 01:57.000]  La deuda está en 21 mil pesos.', '[01:57.000 --> 02:02.000]  Si ella la paga de contado, tiene un descuento muy importante.', '[02:02.000 --> 02:04.000]  Y si no, puede hacer un plan de pagos.', '[02:04.000 --> 02:07.000]  ¿Quiere que le diga cuánto le queda de contado?', '[02:07.000 --> 02:09.000]  Sí, dígame.', '[02:09.000 --> 02:11.000]  ¿Por qué?', '[02:11.000 --> 02:15.000]  Porque tal vez le puede ayudar a alguien y de esta manera ya no puede solucionar.', '[02:15.000 --> 02:17.000]  Sí.', '[02:17.000 --> 02:46.000]  Con 13 mil 500 pesos cancela toda la deuda.', '[02:46.000 --> 02:49.000]  Ajá, con 13 mil 500 pesos.', '[02:49.000 --> 02:51.000]  13 mil 500 pesos.', '[02:51.000 --> 02:54.000]  Y es importante, les cuento, es casi de mil pesos.', '[02:54.000 --> 02:56.000]  Sí, sí.', '[02:56.000 --> 02:58.000]  Es mucha plata.', '[02:58.000 --> 03:00.000]  Sí.', '[03:00.000 --> 03:05.000]  Y eso tiene que ser al contado, si usted se puede hacer en dos veces también.', '[03:05.000 --> 03:09.000]  Vemos, la primera cuando la estaría pagando.', '[03:09.000 --> 03:16.000]  En calculo 15 días, más o menos, porque es hora.', '[03:16.000 --> 03:19.000]  A los sumos 7 días nos permite el banco.', '[03:19.000 --> 03:21.000]  Así lo va a pagar en los meses.', '[03:21.000 --> 03:23.000]  10 días.', '[03:23.000 --> 03:25.000]  Sí.', '[03:25.000 --> 03:30.000]  Sí, más o menos, sí, puede ser en 10 días, sí.', '[03:30.000 --> 03:34.000]  A ver, los vemos. Hacemos la consulta al banco.', '[03:34.000 --> 03:39.000]  Hoy es día 10.', '[03:39.000 --> 03:42.000]  Y 10 para día 20.', '[03:42.000 --> 03:46.000]  Serían dos botas.', '[03:46.000 --> 03:49.000]  Sí, me lo acepto acá al banco.', '[03:49.000 --> 03:58.000]  Sí, sí, sí.', '[03:58.000 --> 04:00.000]  Sí, me lo acepto al banco. ...

# %%
df.Valida.dropna(inplace=True)

# %%
df.Valida.value_counts(), df.Valida.value_counts().sum()
# Out:
# (1.0    626
#  0.0    441
#  9.0      3
#  Name: Valida, dtype: int64, 1070)

# %%
df2.Valida.value_counts(), df2.Valida.value_counts().sum()
# Out:
# (0    535
#  1    504
#  2     10
#  `      1
#  Name: Valida, dtype: int64, 1050)

# %%
df.Valida = df.Valida.astype(str)
df2.Valida = df2.Valida.astype(str)

# %%
df = df[df['Valida'].str.contains('1') != True]
df2 = df2[df2['Valida'].str.contains('0') == True]

# %%
len(df), len(df2)
# Out:
# (1531, 535)

# %%
df.head()
# Out:
#    ID_MOPC      IDMOROSO       IDCLIENTE  OPERADOR  CAMPAÑA  \
# 0   242789  DNI 17446006  HSBC_LEGALES14      1893       13
# 1   242828  DNI 22833374      BSR_TARDIA      1736       75
# 2   252660  DNI 14103422      BSR_TARDIA      3358       75
# 3   252704  DNI 24569175      BSR_TARDIA     15033       75
# 4   281844  DNI 32437164    FRANCES_2012      3456       30
#
#                                  IDGRABACION TIPO_DISCADOR       FECHA  \
# 0  0296415532961-58516182-20210412080350.mp3        Manual  2021-04-12
# 1  0341152104531-58516255-20210412083146.mp3        Manual  2021-04-12
# 2  0352115465488-58539435-20210412145237.mp3        Manual  2021-04-12
# 3       47033002-58539525-20210412145430.mp3        Manual  2021-04-12
# 4     1569041471-58596844-20210414110850.mp3        Manual  2021-04-14
#
#                                      ID  IDLLAMADA  ...  \
# 0  0FE83E97-4556-47AC-A378-BBD3F43E3B2F   58516182  ...
# 1  50B44004-0532-4BC5-8E78-89BD1FFC98AA   58516255  ...
# 2  6FB33DE6-0029-449A-AE8F-20CEF5D418E4   58539435  ...
# 3  EEBBA183-A9CF-4DC3-8B8A-A9FF7056ABAB   58539525  ...
# 4  2DFEA822-C269-437F-9BD1-16CB9B9A01BE   58596844  ...
#
#                                                  LOG DIRECCION IDOPERADOR  \
# 0  |0|0296415532961|SIP/Telular35-0000003e|161822...  SALIENTE    JALTIMA
# 1  |0|0341152104531|SIP/Telular21-000000bc|161822...  SALIENTE   MCARDOZO
# 2  |0|0352115465488|SIP/Telular21-00009175|161825...  SALIENTE    KVISUÑA
# 3  |0|47033002|DAHDI/220-78c|1618250889.44194|16:...  SALIENTE       ROBI
# 4  |0|1569041471|SIP/Telular26-0000353a|161841014...  SALIENTE     MCARDE
#
#    AGENDAMIENTO_ESTADO  anos mes  \
# 0           INTERESADO  2021   4
# 1           INTERESADO  2021   4
# 2           INTERESADO  2021   4
# 3           INTERESADO  2021   4
# 4           INTERESADO  2021   4
#
#                                 transcripcion_limpia  Contestador  \
# 0  m  ibs                                        ...            0
# 1  si     si que tal buen dia alejandra     si   ...            0
# 2  que tal buen dia se encuentra      si     si c...            0
# 3  si buenos dias feliz carlos villegas     no el...            0
# 4  buenas dias se encuentra el senor juan nicolas...            0
#
#                                        transcripcion Valida
# 0  [00:00.000 --> 00:05.000]  Hola, disculpe. Hab...    0.0
# 1  ['[00:00.000 --> 00:01.000]  Hola.', '[00:01.0...    0.0
# 2  ['[00:00.000 --> 00:05.000]  Hola. Hola, ¿qué ...    0.0
# 3  ['[00:00.000 --> 00:05.000]  Hola. Hola. Hola....    nan
# 4  ['[00:00.000 --> 00:02.000]  Hola.', '[00:02.0...    nan
#
# [5 rows x 28 columns]

# %%
df2.head()
# Out:
#     ID_MOPC      IDMOROSO       IDCLIENTE  OPERADOR  CAMPAÑA  \
# 0  242789.0  DNI 17446006  HSBC_LEGALES14    1893.0     13.0
# 1  242828.0  DNI 22833374      BSR_TARDIA    1736.0     75.0
# 2  252660.0  DNI 14103422      BSR_TARDIA    3358.0     75.0
# 3  252704.0  DNI 24569175      BSR_TARDIA   15033.0     75.0
# 4  281844.0  DNI 32437164    FRANCES_2012    3456.0     30.0
#
#                                  IDGRABACION TIPO_DISCADOR  \
# 0  0296415532961-58516182-20210412080350.mp3        Manual
# 1  0341152104531-58516255-20210412083146.mp3        Manual
# 2  0352115465488-58539435-20210412145237.mp3        Manual
# 3       47033002-58539525-20210412145430.mp3        Manual
# 4     1569041471-58596844-20210414110850.mp3        Manual
#
#                      FECHA                                    ID   IDLLAMADA  \
# 0  2021-04-12 00:00:00.000  0FE83E97-4556-47AC-A378-BBD3F43E3B2F  58516182.0
# 1  2021-04-12 00:00:00.000  50B44004-0532-4BC5-8E78-89BD1FFC98AA  58516255.0
# 2  2021-04-12 00:00:00.000  6FB33DE6-0029-449A-AE8F-20CEF5D418E4  58539435.0
# 3  2021-04-12 00:00:00.000  EEBBA183-A9CF-4DC3-8B8A-A9FF7056ABAB  58539525.0
# 4  2021-04-14 00:00:00.000  2DFEA822-C269-437F-9BD1-16CB9B9A01BE  58596844.0
#
#    ...                                                LOG DIRECCION  \
# 0  ...  |0|0296415532961|SIP/Telular35-0000003e|161822...  SALIENTE
# 1  ...  |0|0341152104531|SIP/Telular21-000000bc|161822...  SALIENTE
# 2  ...  |0|0352115465488|SIP/Telular21-00009175|161825...  SALIENTE
# 3  ...  |0|47033002|DAHDI/220-78c|1618250889.44194|16:...  SALIENTE
# 4  ...  |0|1569041471|SIP/Telular26-0000353a|161841014...  SALIENTE
#
#   IDOPERADOR  AGENDAMIENTO_ESTADO    anos  mes  \
# 0    JALTIMA           INTERESADO  2021.0  4.0
# 1   MCARDOZO           INTERESADO  2021.0  4.0
# 2    KVISU��           INTERESADO  2021.0  4.0
# 3       ROBI           INTERESADO  2021.0  4.0
# 4     MCARDE           INTERESADO  2021.0  4.0
#
#                                 transcripcion_limpia  \
# 0  m  ibs                                        ...
# 1  si     si que tal buen dia alejandra     si   ...
# 2  que tal buen dia se encuentra      si     si c...
# 3  si buenos dias feliz carlos villegas     no el...
# 4  buenas dias se encuentra el senor juan nicolas...
#
#                                        transcripcion Contestador Valida
# 0  [00:00.000 --> 00:05.000]  Hola, disculpe. Hab...         0.0      0
# 1  ['[00:00.000 --> 00:01.000]  Hola.', '[00:01.0...         0.0      0
# 2  ['[00:00.000 --> 00:05.000]  Hola. Hola, ¿qué ...         0.0      0
# 3  ['[00:00.000 --> 00:05.000]  Hola. Hola. Hola....         0.0      0
# 4  ['[00:00.000 --> 00:02.000]  Hola.', '[00:02.0...         0.0      0
#
# [5 rows x 28 columns]

# %%
df = pd.concat([df, df2])

# %%
# df = df[df.columns.drop(list(df.filter(regex='Unnamed')))]
# df.drop(columns='level_0', inplace=True)
df.reset_index(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2066 entries, 0 to 2065
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 2066 non-null   int64
#  1   ID_MOPC               2066 non-null   float64
#  2   IDMOROSO              2066 non-null   object
#  3   IDCLIENTE             2066 non-null   object
#  4   OPERADOR              2066 non-null   float64
#  5   CAMPAÑA               2066 non-null   float64
#  6   IDGRABACION           2066 non-null   object
#  7   TIPO_DISCADOR         2066 non-null   object
#  8   FECHA                 2066 non-null   object
#  9   ID                    2066 non-null   object
#  10  IDLLAMADA             2066 non-null   float64
#  11  ESTADO                2066 non-null   object
#  12  SUBESTADO             2066 non-null   object
#  13  F_INICIO              2066 non-null   object
#  14  ANI_TELEFONO          2064 non-null   float64
#  15  GRABACION_DEP         2066 non-null   object
#  16  TIPO                  2066 non-null   object
#  17  CRM                   2066 non-null   float64
#  18  BASE                  2066 non-null   float64
#  19  LOG                   2066 non-null   object
#  20  DIRECCION             2066 non-null   object
#  21  IDOPERADOR            1794 non-null   object
#  22  AGENDAMIENTO_ESTADO   2066 non-null   object
#  23  anos                  2066 non-null   float64
#  24  mes                   2066 non-null   float64
#  25  transcripcion_limpia  2066 non-null   object
#  26  Contestador           2066 non-null   float64
#  27  transcripcion         2066 non-null   object
#  28  Valida                2066 non-null   object
# dtypes: float64(10), int64(1), object(18)
# memory usage: 468.2+ KB

# %%
df.drop_duplicates().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2066 entries, 0 to 2065
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 2066 non-null   int64
#  1   ID_MOPC               2066 non-null   float64
#  2   IDMOROSO              2066 non-null   object
#  3   IDCLIENTE             2066 non-null   object
#  4   OPERADOR              2066 non-null   float64
#  5   CAMPAÑA               2066 non-null   float64
#  6   IDGRABACION           2066 non-null   object
#  7   TIPO_DISCADOR         2066 non-null   object
#  8   FECHA                 2066 non-null   object
#  9   ID                    2066 non-null   object
#  10  IDLLAMADA             2066 non-null   float64
#  11  ESTADO                2066 non-null   object
#  12  SUBESTADO             2066 non-null   object
#  13  F_INICIO              2066 non-null   object
#  14  ANI_TELEFONO          2064 non-null   float64
#  15  GRABACION_DEP         2066 non-null   object
#  16  TIPO                  2066 non-null   object
#  17  CRM                   2066 non-null   float64
#  18  BASE                  2066 non-null   float64
#  19  LOG                   2066 non-null   object
#  20  DIRECCION             2066 non-null   object
#  21  IDOPERADOR            1794 non-null   object
#  22  AGENDAMIENTO_ESTADO   2066 non-null   object
#  23  anos                  2066 non-null   float64
#  24  mes                   2066 non-null   float64
#  25  transcripcion_limpia  2066 non-null   object
#  26  Contestador           2066 non-null   float64
#  27  transcripcion         2066 non-null   object
#  28  Valida                2066 non-null   object
# dtypes: float64(10), int64(1), object(18)
# memory usage: 484.2+ KB

# %%
df.Valida.unique()
# Out:
# array(['0.0', 'nan', '9.0', '0'], dtype=object)

# %%
df = df[df['Valida'].str.contains('nan') != True]

# %%
df.Valida.unique()
# Out:
# array(['0.0', '9.0', '0'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 979 entries, 0 to 2065
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 979 non-null    int64
#  1   ID_MOPC               979 non-null    float64
#  2   IDMOROSO              979 non-null    object
#  3   IDCLIENTE             979 non-null    object
#  4   OPERADOR              979 non-null    float64
#  5   CAMPAÑA               979 non-null    float64
#  6   IDGRABACION           979 non-null    object
#  7   TIPO_DISCADOR         979 non-null    object
#  8   FECHA                 979 non-null    object
#  9   ID                    979 non-null    object
#  10  IDLLAMADA             979 non-null    float64
#  11  ESTADO                979 non-null    object
#  12  SUBESTADO             979 non-null    object
#  13  F_INICIO              979 non-null    object
#  14  ANI_TELEFONO          978 non-null    float64
#  15  GRABACION_DEP         979 non-null    object
#  16  TIPO                  979 non-null    object
#  17  CRM                   979 non-null    float64
#  18  BASE                  979 non-null    float64
#  19  LOG                   979 non-null    object
#  20  DIRECCION             979 non-null    object
#  21  IDOPERADOR            845 non-null    object
#  22  AGENDAMIENTO_ESTADO   979 non-null    object
#  23  anos                  979 non-null    float64
#  24  mes                   979 non-null    float64
#  25  transcripcion_limpia  979 non-null    object
#  26  Contestador           979 non-null    float64
#  27  transcripcion         979 non-null    object
#  28  Valida                979 non-null    object
# dtypes: float64(10), int64(1), object(18)
# memory usage: 229.5+ KB

# %%
transcripciones = df["transcripcion_limpia"]

# %%
df_columns = df.columns.to_list()

# %%
# dfff2 = df2.columns.to_list()

# %%
# l3 = [x for x in dfff2 if x not in df_columns]

# %%
# l3

# %%
# l3 = ['Saludo',
#  'Oferta',
#  'Aceptacion',
#  'Whatssapp',
#  'Modo_pago',
#  'Trabajando',
#  'Transferencia',
#  'Paga',
#  'Despedida',
#  'Trabajo',
#  'Tarjeta',
#  'Deuda',
#  'Reclamo',
#  'Ayudar',
#  'Asentado',
#  'Renovacion',
#  'Pago',
#  'Refinanciacion',
#  'Cumplir',
#  'Voluntad',
#  'Agendar',
#  '`Trabajo',
#  'Acuerdo',
#  'Hablar',
#  'Entidades',
#  'Bonificacion',
#  'Resolver',
#  'Baja',
#  'Ayuda',
#  'Posibilidades',
#  'Renovar',
#  'Refinanciar',
#  'Posibilidad',
#  'Numero',
#  'Depositar',
#  'Comunico',
#  'Saldo',
#  'Cuota',
#  'Pauta',
#  'Banco',
#  'Utilizar',
#  'Cancela',
#  'Sistemas',
#  'Libre_deuda',
#  'Pendiente',
#  'Acreditado',
#  'Deposito',
#  'Problema',
#  'Informacion',
#  'Autorizacion',
#  'Metodo_pago',
#  'Email',
#  'Reactivacion',
#  'Datos',
#  'Contacto',
#  'Vacuna',
#  'Descuento',
#  'Opcion',
#  'Cuotas',
#  'Esfuerzo',
#  'Intencion',
#  'Grabar',
#  'Negociacion',
#  'Turno',
#  'Propuesta',
#  'Solucion',
#  'Gracias',
#  'Manejar',
#  'Solicitud',
#  'Vencimiento',
#  'Seguimiento',
#  'Comprobante',
#  'Plan',
#  'Pagar',
#  'Abonar',
#  'luego',
#  'Confirmado',
#  'Contactar',
#  'Cbu',
#  'Estafa',
#  'Llamadas',
#  'Telefono',
#  'Dinero',
#  'Ofrecer',
#  'Confirmar',
#  'Ordenar',
#  'Esperar',
#  'Llamar',
#  'Inconveniente',
#  'Llamado',
#  'Correo',
#  'Regularizar',
#  'Mensaje',
#  'Atender',
#  'Registro',
#  'Interes',
#  'Financiar',
#  'Banking',
#  'Usuario',
#  'Sucursal',
#  'Enviar',
#  'Abogado',
#  'Legales',
#  'Situacion',
#  'Cobrar',
#  'Retraso',
#  'Contestacion',
#  'Negativo',
#  'Atraso',
#  'Aislamiento',
#  'Semana',
#  'Beneficio',
#  'Cancelar',
#  'Cuenta',
#  'Informar',
#  'Plata',
#  'Judicial',
#  'Credito',
#  'Asesorar',
#  'Cobranza',
#  'Duda',
#  'Mopc',
#  'Laburo',
#  'Localizar',
#  'Plazo',
#  'Cortar',
#  'Legajo',
#  'Honorarios',
#  'Tiempo',
#  'Comunicar',
#  'Recordatorio',
#  'Avisar',
#  'Internet',
#  'Arreglar',
#  'Resumen',
#  'Clave',
#  'Importe',
#  'Pandemia',
#  'Familia',
#  'Intereses',
#  'Analizar']

# %%
# from gensim.models import Word2Vec
# word2vec = Word2Vec(sentences=transcripciones)

# %%
# word2vec.wv.most_similar('familia', topn=10)

# %%
# import gensim.downloader as api
# word_vectors = api.load("glove-wiki-gigaword-100")  # load pre-trained word-vectors from gensim-data
# # Check the "most similar words", using the default "cosine similarity" measure.
# # result = word_vectors.most_similar('hola')

# %%
# word_vectors.most_similar('saludo')

# %%
# result

# %%
# from gensim.models import KeyedVectors
# word_vectors.save('vectors.kv')
# reloaded_word_vectors = KeyedVectors.load('vectors.kv', mmap='r')

# %%
# reloaded_word_vectors.most_similar('oferta')

# %%
# for n in range(10):
#   try:
#     print(f''+ str(l3[n]) + ': \n' + str(reloaded_word_vectors.most_similar(l3[n].lower())))
#   except:
#     KeyError

# %%
# import requests
# from bs4 import BeautifulSoup
# url='http://www.wordreference.com/sinonimos/'
# for n in range(10):
#   enlace=l3[n].replace('_','')
#   buscar=url+enlace
#   resp=requests.get(buscar)
#   bs=BeautifulSoup(resp.text,'lxml')
#   lista=bs.find_all(class_='trans clickable')
#   for sin in lista:
#       sino=sin.find_all('li')
#       for fin in sino:
#           print(f''+ str(enlace) + ': \n' + str(fin.next_element))

# %%
# palabras = []
# for transcripcion in transcripciones:
#     palabras.extend(nltk.word_tokenize(transcripcion))

# fdist = nltk.FreqDist(palabras)
# palabras_clave = fdist.most_common(10)

# from sklearn.decomposition import LatentDirichletAllocation

# vectorizer = CountVectorizer()
# X = vectorizer.fit_transform(transcripciones)
# lda = LatentDirichletAllocation(n_components=10)
# lda.fit(X)

# temas = []
# for topic in lda.components_:
#     tema = " ".join([vectorizer.get_feature_names()[i] for i in topic.argsort()[:-10 - 1:-1]])
#     temas.append(tema)

# %%
new_stopwords = ['si',
 'bueno',
 'banco',
 'usted',
 'tardes',
 'buenas',
#  'pago',
#  'deuda',
 'bien',
 'mas',
 'dias',
 'hacer',
 'senor',
 'ver',
 'puedo',
#  'cuotas',
 'va',
 'gracias',
 'perfecto',
 'puede',
 'ahora',
 'voy',
 'dia',
 'entonces',
 'buenos',
 'claro',
 'numero',
 'senora',
 'ah',
 'ok',
 'asi',
 'tal',
 'ahi',
 'favor',
 'manana',
 'luego',
 'estudio',
#  'pagar',
 'dale',
 'mes',
 'plan',
 'hablar',
 'agencia',
 'hola',
 'cómo',
 'ahí',
 'así',
 'día',
 'como',
 'ahi',
 'asi',
 'dia']

# %%
def get_keywords(columna):
  stpwrd = nltk.corpus.stopwords.words('spanish')
  stpwrd.extend(new_stopwords)
  vectorizer = TfidfVectorizer(stop_words=stpwrd)
  X = vectorizer.fit_transform(columna)
  features = vectorizer.get_feature_names()
  scores = X.toarray().sum(axis=0)
  keywords = [features[i] for i in scores.argsort()[::-1][:20]]
  return keywords

# %%
get_keywords(df['transcripcion_limpia'])
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['pago',
#  'deuda',
#  'cuotas',
#  'pesos',
#  'whatsapp',
#  'pagar',
#  'tarjeta',
#  'cuenta',
#  'hoy',
#  'saldo',
#  'dos',
#  'descuento',
#  'mil',
#  'tres',
#  'despues',
#  'pueda',
#  'cuota',
#  'telefono',
#  'semana',
#  'poder']

# %%
def palbras_mas_importantes(turnos):
    # Tokenizamos los turnos de habla
    tokenizer = RegexpTokenizer(r'\w+')
    df['turnos_tokenizados'] = turnos.apply(lambda x: tokenizer.tokenize(x))

    # Eliminamos las stopwords
    stpwrd = nltk.corpus.stopwords.words('spanish')
    stpwrd.extend(new_stopwords)
    df['turnos_filtrados'] = df['turnos_tokenizados'].apply(lambda x: [word for word in x if word not in stpwrd])

    # Lematizamos los turnos de habla
    lemmatizer = WordNetLemmatizer()
    df['turnos_lematizados'] = df['turnos_filtrados'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])

    # Calculamos la longitud promedio de los turnos de habla
    df['longitud_turnos'] = df['turnos_lematizados'].apply(lambda x: len(x))
    longitud_promedio = df['longitud_turnos'].mean()

    # Calculamos los temas principales
    palabras = []
    for turno in df['turnos_lematizados']:
        palabras.extend(turno)
    frecuencia = pd.Series(palabras).value_counts()
    palbras_mas_importantes = frecuencia[:10]

    # Calculamos las palabras clave
    palabras_clave = []
    for turno in df['turnos_lematizados']:
        for palabra in turno:
            if palabra not in palabras_clave and palabra not in stpwrd:
                palabras_clave.append(palabra)
    return palbras_mas_importantes, palabras

# %%
# palbras_mas_importantes(df['transcripcion_limpia'])

# %%
transcripciones = palbras_mas_importantes(df['transcripcion_limpia'])[1]

# %%
transcripciones
# Out:
# ['m',
#  'ibs',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'mm',
#  'mib',
#  'disculpe',
#  'hablo',
#  'sena',
#  'celia',
#  'guillermina',
#  'silva',
#  'saludo',
#  'ion',
#  'gabanas',
#  'juridico',
#  'mopc',
#  'representacion',
#  'santander',
#  'todavia',
#  'comunico',
#  'referente',
#  'saldo',
#  'pendiente',
#  'peso',
#  'seria',
#  'comunico',
#  'habla',
#  'habla',
#  'comunico',
#  'juridico',
#  'saldo',
#  'pendiente',
#  'santander',
#  'pregunteria',
#  'descuento',
#  'saldo',
#  'quedaria',
#  'alguna',
#  'posibilidad',
#  'pueda',
#  'cancelar',
#  'monto',
#  'celia',
#  'unico',
#  'cancelar',
#  'jubilada',
#  'sola',
#  'exactamente',
#  'mensualmente',
#  'peso',
#  'pueda',
#  'origen',
#  'podria',
#  'empezar',
#  'poner',
#  'viste',
#  'jubilada',
#  'sola',
#  'viste',
#  'comento',
#  'maximo',
#  'pueda',
#  'cuotas',
#  'serian',
#  'cuotas',
#  'peso',
#  'escucha',
#  'entiendo',
#  'pueda',
#  'saldo',
#  'pendiente',
#  'viste',
#  'situacion',
#  'hace',
#  'do',
#  'ano',
#  'celia',
#  'sola',
#  'jubilada',
#  'minimum',
#  'haga',
#  'posible',
#  'poder',
#  'conseguirlo',
#  'caso',
#  'estaria',
#  'accionando',
#  'celia',
#  'entiendo',
#  'dice',
#  'situacion',
#  'saldo',
#  'pendiente',
#  'atraso',
#  'do',
#  'ano',
#  'atraso',
#  'celia',
#  'caso',
#  'envio',
#  'propuesta',
#  'whatsapp',
#  'acaso',
#  'celia',
#  'llama',
#  'aca',
#  'telefono',
#  'tampoco',
#  'aca',
#  'linea',
#  'correo',
#  'electronico',
#  'acaso',
#  'algun',
#  'correo',
#  'electronico',
#  'acaso',
#  'hablo',
#  'entiendo',
#  'dejo',
#  'notado',
#  'cambium',
#  'opinion',
#  'proxima',
#  'llamada',
#  'comentenos',
#  'celia',
#  'cuanto',
#  'dice',
#  'podria',
#  'juntar',
#  'dice',
#  'recomiendo',
#  'dice',
#  'entiendo',
#  'vos',
#  'vos',
#  'tenes',
#  'viste',
#  'escuchas',
#  'escucho',
#  'cabezas',
#  'anda',
#  'mal',
#  'viste',
#  'haga',
#  'posible',
#  'caso',
#  'paso',
#  'informe',
#  'dice',
#  'vos',
#  'llamame',
#  'pues',
#  'llama',
#  'juntar',
#  'viste',
#  'entiendo',
#  'estaria',
#  'pasando',
#  'informe',
#  'comunico',
#  'caso',
#  'viernes',
#  'llama',
#  'aca',
#  'mismo',
#  'nino',
#  'igualmente',
#  'buen',
#  'alejandra',
#  'alejandra',
#  'maria',
#  'carmen',
#  'habla',
#  'mipc',
#  'santander',
#  'rio',
#  'diganme',
#  'llamamos',
#  'justamente',
#  'podiamos',
#  'confirmar',
#  'propuesta',
#  'enviado',
#  'whatsapp',
#  'hablando',
#  'telefonicamente',
#  'poder',
#  'resolverlo',
#  'hizo',
#  'dificil',
#  'situacion',
#  'vuelvo',
#  'quedar',
#  'trabajo',
#  'hizo',
#  'mal',
#  'verdad',
#  'decirte',
#  'bonificacion',
#  'bajaba',
#  'verdad',
#  'conveniente',
#  'entiendo',
#  'situacion',
#  'alejandra',
#  'necesitas',
#  'confirmarlo',
#  'resolver',
#  'espero',
#  'resuelva',
#  'mejor',
#  'manera',
#  'digo',
#  'dijeron',
#  'verdad',
#  'disparar',
#  'sabia',
#  'cualquier',
#  'momento',
#  'iba',
#  'llamar',
#  'tenia',
#  'imagino',
#  'iba',
#  'llamar',
#  'semana',
#  'sabia',
#  'iba',
#  'decir',
#  'entero',
#  'novedad',
#  'verdad',
#  'decirte',
#  'desconservacion',
#  'verdad',
#  'tenia',
#  'organizado',
#  'dice',
#  'dije',
#  'primeros',
#  'sabia',
#  'paso',
#  'solo',
#  'pandemia',
#  'parece',
#  'afecta',
#  'viste',
#  'cadena',
#  'queda',
#  'trabajo',
#  'obviamente',
#  'quedo',
#  'trabajo',
#  'tambien',
#  'alejandra',
#  'quieres',
#  'haber',
#  'propuesta',
#  'camame',
#  'vuelta',
#  'propuesta',
#  'digamos',
#  'acuerdo',
#  'extenso',
#  'menos',
#  'bonificacion',
#  'realidad',
#  'tampoco',
#  'conviene',
#  'menos',
#  'bonificacion',
#  'podemos',
#  'ofrecerla',
#  'cuotas',
#  'baja',
#  'muchisimo',
#  'tambien',
#  'cada',
#  'cuota',
#  'tres',
#  'resuelve',
#  'pago',
#  'cuota',
#  'seria',
#  'tres',
#  'cuotas',
#  'entiendo',
#  'situacion',
#  'dependiendo',
#  'van',
#  'informando',
#  'trabajo',
#  'digo',
#  'llega',
#  'tener',
#  'resolucion',
#  'mantener',
#  'bonificacion',
#  'poderlo',
#  'informar',
#  'aviseme',
#  'whatsapp',
#  'informan',
#  'trabajo',
#  'pueden',
#  'resolver',
#  'distinto',
#  'modo',
#  'resolver',
#  'tambien',
#  'tenia',
#  'basicamente',
#  'dije',
#  'resuelta',
#  'viste',
#  'decia',
#  'esperad',
#  'fijate',
#  'dio',
#  'miedo',
#  'meterme',
#  'viste',
#  'pagar',
#  'primera',
#  'cuota',
#  'despues',
#  'tema',
#  'pago',
#  'primera',
#  'cuota',
#  'despues',
#  'segunda',
#  'hago',
#  'prefiero',
#  'dejemos',
#  'pasar',
#  'informan',
#  'fungen',
#  'poder',
#  'cumplir',
#  'digamos',
#  'pactado',
#  'seccion',
#  'digo',
#  'mande',
#  'vuelta',
#  'whatsapp',
#  'vos',
#  'sabes',
#  'agende',
#  'viste',
#  'agende',
#  'viste',
#  'vos',
#  'agende',
#  'nombre',
#  'quiero',
#  'agendar',
#  'queda',
#  'registrado',
#  'privado',
#  'viste',
#  'manda',
#  'manejado',
#  'repito',
#  'mismo',
#  'mensaje',
#  'mande',
#  'cosas',
#  'presente',
#  'pongo',
#  'banca',
#  'entender',
#  'olvidar',
#  'vuelta',
#  'cualquier',
#  'cosa',
#  'escribe',
#  'whatsapp',
#  'mande',
#  'rendi',
#  'mensajito',
#  'cuente',
#  'nombre',
#  'maria',
#  'elcarpe',
#  'olvide',
#  'maria',
#  'elcarpe',
#  'buen',
#  'salud',
#  'buen',
#  'salud',
#  'vos',
#  'tambien',
#  'buen',
#  'buen',
#  'encuentra',
#  'gisi',
#  'ivana',
#  'ivana',
#  'llamando',
#  'deposito',
#  'santander',
#  'rio',
#  'pidiendo',
#  'fique',
#  'santander',
#  'rio',
#  'deposito',
#  'abril',
#  'peso',
#  'cancelar',
#  'deuda',
#  'tema',
#  'responde',
#  'mensajes',
#  'pago',
#  'hoy',
#  'vuelve',
#  'inicial',
#  'deuda',
#  'pierde',
#  'bonificacion',
#  'ofrecio',
#  'primero',
#  'hizo',
#  'tenia',
#  'explique',
#  'deuda',
#  'estan',
#  'cobrando',
#  'bono',
#  'deuda',
#  'activa',
#  'informa',
#  'deuda',
#  'deuda',
#  'cierto',
#  'moro',
#  'menos',
#  'momento',
#  'bono',
#  'envio',
#  'comprobante',
#  'envio',
#  'comprobante',
#  'diciendo',
#  'toda',
#  'veces',
#  'iba',
#  'ir',
#  'iba',
#  'pago',
#  'pasa',
#  'comento',
#  'haciendo',
#  'pago',
#  'despues',
#  'dejo',
#  'abonar',
#  'obviamente',
#  'cuotas',
#  'paga',
#  'deja',
#  'pagar',
#  'restante',
#  'deuda',
#  'queda',
#  'cancelada',
#  'abonado',
#  'pago',
#  'subio',
#  'intereses',
#  'cumplio',
#  'acuerdo',
#  'paso',
#  'caso',
#  'dejo',
#  'pagar',
#  'cuotas',
#  'dio',
#  'debajo',
#  'pago',
#  'subio',
#  'intereses',
#  'decirme',
#  'cuanto',
#  'debe',
#  'poner',
#  'respetar',
#  'acuerdo',
#  'envio',
#  'deuda',
#  'peso',
#  'aproximadamente',
#  'buen',
#  'abonifico',
#  'quita',
#  'aproximadamente',
#  'pague',
#  'tarde',
#  'tema',
#  'pidiendo',
#  'ticket',
#  'cuenta',
#  'dio',
#  'abrio',
#  'cuenta',
#  'pague',
#  'preguntando',
#  'partir',
#  'meterse',
#  'cliente',
#  'da',
#  'cuenta',
#  'pague',
#  'ir',
#  'tarjeta',
#  'cuenta',
#  'pagar',
#  'trajero',
#  'automatico',
#  'transferencia',
#  'cuenta',
#  'cuenta',
#  'abrio',
#  'desaparecimos',
#  'dando',
#  'respuesta',
#  'esperando',
#  'ingrese',
#  'dinero',
#  'cuenta',
#  'abrio',
#  'dando',
#  'respuesta',
#  'siempre',
#  'llaman',
#  'tema',
#  'mama',
#  'isi',
#  'mama',
#  'isi',
#  'entendes',
#  'mama',
#  'igual',
#  'mandando',
#  'whatsapp',
#  'telefono',
#  'despues',
#  'estan',
#  'mandando',
#  'tambien',
#  'correo',
#  'hablo',
#  'igual',
#  'mandando',
#  'whatsapp',
#  'telefono',
#  'termina',
#  'refiero',
#  'contesta',
#  'telefono',
#  'dejo',
#  'particula',
#  'contestar',
#  'entiende',
#  'decir',
#  'entiende',
#  'permiten',
#  'trabajo',
#  'mandando',
#  'whatsapp',
#  'tampoco',
#  'contesta',
#  'tres',
#  'jueves',
#  'escribimos',
#  'recordandole',
#  'pago',
#  'escribio',
#  'primera',
#  'hora',
#  'escribio',
#  'escribio',
#  'tarde',
#  'escribio',
#  'tarde',
#  'mensajes',
#  'lee',
#  'telefono',
#  'whatsapp',
#  'hace',
#  'falta',
#  'asamar',
#  'do',
#  'segundos',
#  'abre',
#  'mensaje',
#  'contesta',
#  'presentar',
#  'digo',
#  'cliente',
#  'interesa',
#  'cobrarle',
#  'total',
#  'pasar',
#  'legales',
#  'pierdo',
#  'tiempo',
#  'cliente',
#  'quiere',
#  'pagar',
#  'motones',
#  'udores',
#  'cobrar',
#  'diciendo',
#  'diciendo',
#  'tema',
#  'dijo',
#  'habia',
#  'pagado',
#  'listo',
#  'hoy',
#  'hablo',
#  'pagar',
#  'mil',
#  'peso',
#  'pense',
#  'hoy',
#  'tardar',
#  'primera',
#  'hora',
#  'montre',
#  'ticket',
#  'hoy',
#  'digo',
#  'espera',
#  'mediodia',
#  'cobra',
#  'total',
#  'producto',
#  'hoy',
#  'doy',
#  'baja',
#  'sino',
#  'pagar',
#  'directamente',
#  'dame',
#  'tiempo',
#  'podium',
#  'tratar',
#  'trabajan',
#  'negocio',
#  'tema',
#  'rapido',
#  'debe',
#  'tener',
#  'tiempo',
#  'disponible',
#  'contestar',
#  'crean',
#  'tan',
#  'actibles',
#  'vamos',
#  'sino',
#  'medimos',
#  'pagado',
#  'extrano',
#  'dijo',
#  'venia',
#  'pagando',
#  'pago',
#  'despues',
#  'dejo',
#  'pagar',
#  'diciendo',
#  'hizo',
#  'licueta',
#  'pago',
#  'seis',
#  'pidio',
#  'cuatro',
#  'cambio',
#  'perfectamente',
#  'dame',
#  'tiempo',
#  'pago',
#  'pague',
#  'despues',
#  'peso',
#  'teneis',
#  'quede',
#  'listo',
#  'tema',
#  'pasa',
#  'plazo',
#  'tiempo',
#  'detectar',
#  'solvencia',
#  'pago',
#  'embarga',
#  'mora',
#  'quiere',
#  'llegar',
#  'toque',
#  'sueldo',
#  'hace',
#  'solvencia',
#  'cobrar',
#  'haciendo',
#  'negociacion',
#  'previa',
#  'llegue',
#  'instancia',
#  'solo',
#  'despues',
#  'cualquier',
#  'cosa',
#  'escriba',
#  'tome',
#  'molestia',
#  'agarre',
#  'telefono',
#  'responder',
#  'practicos',
#  'hoy',
#  'mensajito',
#  'soluciona',
#  'horario',
#  'descanso',
#  'break',
#  'escribir',
#  'diez',
#  'noche',
#  'siguiente',
#  'respondo',
#  'horario',
#  'puedes',
#  'escribirme',
#  'cualquier',
#  'horario',
#  'salvo',
#  'trabaje',
#  'horas',
#  'supongo',
#  'debe',
#  'tener',
#  'algun',
#  'horario',
#  'descanso',
#  'contestar',
#  'listo',
#  'lugar',
#  'digo',
#  'darme',
#  'tiempo',
#  'listo',
#  'maria',
#  'escucha',
#  'corton',
#  'escucho',
#  'escucho',
#  'deuda',
#  'presenta',
#  'fecha',
#  'peso',
#  'solo',
#  'ofrecer',
#  'cancele',
#  'descuento',
#  'abril',
#  'vence',
#  'martes',
#  'viene',
#  'descuento',
#  'martes',
#  'descuento',
#  'dar',
#  'casi',
#  'cancelan',
#  'deuda',
#  'pagar',
#  'martes',
#  'viene',
#  'mando',
#  'link',
#  'algun',
#  'codigo',
#  'pueda',
#  'pagar',
#  'enviar',
#  'whatsapp',
#  'enviar',
#  'whatsapp',
#  'pago',
#  'mediodia',
#  'tardar',
#  'horas',
#  'horario',
#  'entregar',
#  'ticket',
#  'ahorita',
#  'agregar',
#  'whatsapp',
#  'pasar',
#  'cuenta',
#  'pagar',
#  'cuenta',
#  'corriente',
#  'cbu',
#  'ir',
#  'cualquier',
#  'santander',
#  'cuenta',
#  'corriente',
#  'hace',
#  'transferencia',
#  'cbu',
#  'cualquiera',
#  'do',
#  'formas',
#  'necesito',
#  'ticket',
#  'trabajando',
#  'mire',
#  'directora',
#  'escuela',
#  'bastante',
#  'complicados',
#  'tema',
#  'covid',
#  'trabajando',
#  'personal',
#  'reducido',
#  'transferencia',
#  'ser',
#  'mejor',
#  'problema',
#  'pasar',
#  'cbu',
#  'hace',
#  'transferencia',
#  'paga',
#  'saco',
#  'foto',
#  'ticket',
#  'envia',
#  'whatsapp',
#  'cargo',
#  'cancelacion',
#  'mismo',
#  'whatsapp',
#  'mismo',
#  'whatsapp',
#  'escribir',
#  ...]

# %%
# def obtener_palabras_clave(transcripciones):
#     from rake_nltk import Rake
#     r = Rake()
#     keywords = []
#     for transcripcion in transcripciones:
#         r.extract_keywords_from_text(transcripcion)
#         keywords.append(r.get_ranked_phrases())
#     return keywords

# %%
# !python -m spacy download es_dep_news_trf
import spacy
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-01-30 12:58:45.489825: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting es-dep-news-trf==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_dep_news_trf-3.4.0/es_dep_news_trf-3.4.0-py3-none-any.whl (410.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.2/410.2 MB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from es-dep-news-trf==3.4.0) (3.4.4)
# Requirement already satisfied: spacy-transformers<1.2.0,>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from es-dep-news-trf==3.4.0) (1.1.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (8.1.6)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (3.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (0.7.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (2.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (21.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (2.11.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (57.4.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (6.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (2.4.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (1.0.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (2.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (3.0.11)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (1.0.9)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (1.21.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (2.25.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (1.10.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (4.64.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.4.0) (1.13.1+cu116)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /usr/local/lib/python3.8/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.4.0) (0.9.0)
# Requirement already satisfied: transformers<4.26.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.4.0) (4.25.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (2.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (0.7.9)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.4.0) (0.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.4.0) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.4.0) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.4.0) (0.12.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers<1.2.0,>=1.1.2->es-dep-news-trf==3.4.0) (2022.6.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->es-dep-news-trf==3.4.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_dep_news_trf')

# %%
# !pip install spacy-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy-transformers in /usr/local/lib/python3.8/dist-packages (1.1.9)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from spacy-transformers) (1.13.1+cu116)
# Requirement already satisfied: spacy<4.0.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy-transformers) (3.4.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy-transformers) (2.4.5)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /usr/local/lib/python3.8/dist-packages (from spacy-transformers) (0.9.0)
# Requirement already satisfied: transformers<4.26.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy-transformers) (4.25.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (2.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (1.0.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (4.64.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (2.25.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (8.1.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (1.10.4)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (0.7.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (6.3.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (0.10.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (3.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (3.0.11)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (21.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (57.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (1.21.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (1.0.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (0.10.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (2.11.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.6.0->spacy-transformers) (4.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers) (3.9.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers) (0.13.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from transformers<4.26.0,>=3.4.0->spacy-transformers) (0.12.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (1.24.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<4.0.0,>=3.4.0->spacy-transformers) (2.0.1)

# %%
def identify_topics(dialogs, n_topics=5, n_words=10):
    # Procesamiento del texto con spaCy
    nlp = spacy.load('es_dep_news_trf')
    docs = [nlp(dialog) for dialog in dialogs]
    
    # Construcción del diccionario y la matriz de términos
    stpwrd = nltk.corpus.stopwords.words('spanish')
    stpwrd.extend(new_stopwords)
    cv = CountVectorizer(stop_words=stpwrd)
    word_count = cv.fit_transform(dialogs)
    word_list = cv.get_feature_names()
    
    # Entrenamiento del modelo LDA
    lda = LatentDirichletAllocation(n_components=n_topics, random_state=42)
    lda.fit(word_count)
    
    # Extracción de los tópicos principales
    top_topics = []
    for topic_idx, topic in enumerate(lda.components_):
        top_words = [word_list[i] for i in topic.argsort()[:-n_words - 1:-1]]
        top_topics.append(top_words)
    
    return top_topics

# %%
# identify_topics(transcripciones)

# %%
temas = ['pago',
 'suscribete',
 'deuda',
 'mensaje',
 'telefono',
 'pesos',
 'whatsapp',
 'cuotas',
 'pagar',
 'hoy',
 'tarjeta',
 'familia',
 'trabajo']

# %%
def obtener_frase(df):
  filas = []

  # Itera sobre cada fila del dataframe
  for index, row in compromiso.iterrows():
    # Extrae la lista de frases de la fila
    frases = row['frases']
    
    # Crea un diccionario vacío para almacenar las frases por tema para la fila actual
    frases_por_tema = {}
    
    # Itera sobre cada tema
    for tema in temas:
      # Itera sobre cada frase
      for frase in frases:
        # Comprueba si la frase contiene el tema actual
        if tema in frase:
          # Añade la frase al diccionario si no existe aún una lista para el tema
          if tema not in frases_por_tema:
            frases_por_tema[tema] = []
          # Añade la frase a la lista del diccionario correspondiente al tema
          frases_por_tema[tema].append(frase)
    
    # Añade el diccionario a la lista de diccionarios
    filas.append(frases_por_tema)

    #Transformalo a Dataframe 
  frases_claves = pd.DataFrame.from_records(filas)

  return frases_claves

# %%
compromiso = df[df['AGENDAMIENTO_ESTADO'].str.contains('COMPROMISO') == True]
# compromiso.drop(columns='level_0', inplace=True)
compromiso.reset_index(inplace=True)

# %%
compromiso['frases'] = None
for n in range(len(compromiso)):
  compromiso['frases'][n] = re.split(r'\s{2,}', compromiso.transcripcion_limpia[n])
# Out:
# <ipython-input-57-65e6958bc711>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   compromiso['frases'] = None
# <ipython-input-57-65e6958bc711>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   compromiso['frases'][n] = re.split(r'\s{2,}', compromiso.transcripcion_limpia[n])

# %%
prueba = obtener_frase(compromiso)
prueba.head()
# Out:
#                                                 pago  \
# 0    [el pago tiene que estar antes del mediodia si]
# 1  [si senor como verifico que usted ya pago la d...
# 2  [eso te queria decir porque ella pago, o sino ...
# 3  [para cuando podriamos agendar otra vez su pag...
# 4  [mientras yo espero el pago la acreditacion de...
#
#                                                deuda  \
# 0  [bien la deuda que presenta el dia de la fecha...
# 1  [si senor como verifico que usted ya pago la d...
# 2  [la deuda que presenta a usted o su esposo es ...
# 3                                                NaN
# 4                                                NaN
#
#                                                pesos  \
# 0                                            [pesos]
# 1  [pesos si tengo que hacerle nuevamente un plan...
# 2                                                NaN
# 3                                                NaN
# 4  [si senora soy yo ayer ya se le depositaron ot...
#
#                                             whatsapp  \
# 0  [yo le voy a enviar tiene whatsapp en este num...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                pagar  \
# 0  [perfecto pero lo puedo pagar el martes que vi...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [claro que ayer se pagaron cinco mil mas bueno...
#
#                                             telefono  \
# 0                                                NaN
# 1                                                NaN
# 2  [este telefono se lo le dan a mi marido que ti...
# 3                                                NaN
# 4                                                NaN
#
#                                              tarjeta cuotas familia  hoy  \
# 0                                                NaN    NaN     NaN  NaN
# 1                                                NaN    NaN     NaN  NaN
# 2  [este telefono se lo le dan a mi marido que ti...    NaN     NaN  NaN
# 3                                                NaN    NaN     NaN  NaN
# 4  [ah ok bueno si jacobo los cinco mil anteriore...    NaN     NaN  NaN
#
#   trabajo mensaje suscribete
# 0     NaN     NaN        NaN
# 1     NaN     NaN        NaN
# 2     NaN     NaN        NaN
# 3     NaN     NaN        NaN
# 4     NaN     NaN        NaN

# %%
prueba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   pago        221 non-null    object
#  1   deuda       161 non-null    object
#  2   pesos       150 non-null    object
#  3   whatsapp    151 non-null    object
#  4   pagar       142 non-null    object
#  5   telefono    69 non-null     object
#  6   tarjeta     82 non-null     object
#  7   cuotas      83 non-null     object
#  8   familia     26 non-null     object
#  9   hoy         112 non-null    object
#  10  trabajo     73 non-null     object
#  11  mensaje     66 non-null     object
#  12  suscribete  1 non-null      object
# dtypes: object(13)
# memory usage: 26.5+ KB

# %%
compromiso.frases[0]
# Out:
# ['si maria me escucha este corton',
#  'si le escucho le escucho',
#  'bien la deuda que presenta el dia de la fecha son',
#  'pesos',
#  'y solo que le puedo ofrecer para que cancele con el descuento de este mes de abril',
#  'que vence el martes que viene es un descuento mas',
#  'no manana',
#  'no manana el otro el otro martes',
#  'es un descuento que le puedo dar del',
#  'casi',
#  'con',
#  'cancelan la deuda',
#  'perfecto pero lo puedo pagar el martes que viene',
#  'si usted le mando un link o algun codigo o algo para que yo pueda pagar',
#  'yo le voy a enviar tiene whatsapp en este numero',
#  'si',
#  'bueno yo le voy a enviar un whatsapp',
#  'el pago tiene que estar antes del mediodia si',
#  'a mas tardar a las',
#  'horas porque en ese horario hay que entregar los tickets al banco si',
#  'ahorita la voy a agregar al whatsapp y le voy a pasar el numero de cuenta donde tiene que pagar',
#  'es una cuenta corriente o un cbu',
#  'puede ir a cualquier santander con la cuenta corriente',
#  'o si no hace una transferencia con el cbu',
#  'cualquiera de las dos formas luego necesito el ticket',
#  'estoy trabajando y mire yo soy directora de una escuela',
#  'estamos bastante complicados con este tema del covid',
#  'y bueno estamos trabajando con personal reducido',
#  'por eso si yo le puedo hacer una transferencia va a ser mejor',
#  'si no hay problema',
#  'ahi en el numero que le voy a pasar tiene el cbu hace la transferencia',
#  'cuando paga le saco una foto al ticket y me lo envia por whatsapp',
#  'y cargo la cancelacion',
#  'por el mismo whatsapp',
#  'el mismo whatsapp que yo le voy a escribir en unos minutos',
#  'esta apenas termina de cargar el acuerdo en el banco',
#  'perfecto',
#  'listo maria ahora agendo al whatsapp y le paso los datos',
#  'bueno le agradezco mucho',
#  'no de nada que tenga buen dia',
#  'muchas gracias']

# %%
def analisis_sentimientos_bert(df):
  # Crea una nueva columna en el dataframe para almacenar el resultado del análisis de sentimientos
  df['sentimiento'] = None

  # Crea una instancia del tokenizador de BERT que soporte el idioma español
  tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')

  # Carga el modelo pre-entrenado de BERT para clasificación de secuencias que soporte el idioma español
  model = BertForSequenceClassification.from_pretrained('bert-base-multilingual-cased', num_labels=4)

  # Itera sobre cada fila del dataframe
  for index, row in df.iterrows():
    # Obtiene el texto de la columna transcripcion_limpia de la fila actual
    texto = row['frases']

    # Tokeniza el texto y lo convierte en un tensor de PyTorch
    input_ids = torch.tensor(tokenizer.encode(texto, add_special_tokens=True)).unsqueeze(0)  # agrega dos dimensiones adicional para hacerlo compatible con el modelo BERT

    # Ejecuta el modelo BERT para clasificar la secuencia de tokens
    logits = model(input_ids)[0]

    # Obtiene la probabilidad de cada clase (positiva y negativa)
    probabilidades = torch.nn.functional.softmax(logits, dim=0)

    # Obtiene la clase con mayor probabilidad
    clase_predicha = probabilidades.argmax().item()

# Asigna el sentimiento a la columna sentimiento del dataframe según la clase predicha
    if clase_predicha == 0:
      df.loc[index, 'sentimiento'] = 'positivo'
    else:
      df.loc[index, 'sentimiento'] = 'negativo'

# %%
df.drop(0, inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df['frases'] = None
for n in range(len(df)):
  df['frases'][n] = re.split(r'\s{2,}', str(df.transcripcion_limpia[n]))
# Out:
# <ipython-input-69-1b634f6c50f9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['frases'][n] = re.split(r'\s{2,}', str(df.transcripcion_limpia[n]))

# %%
analisis_sentimientos_bert(df)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Token indices sequence length is longer than the specified maximum sequence length for this model (521 > 512). Running this sequence through the model will result in indexing errors

# %%
compromiso.head()

# %%
compromiso.longitud_turnos.value_counts()

# %%
df.Valida.value_counts()

# %%
df.sentimiento.value_counts() # df negativo    1432 positivo     844
# Out:
# negativo    740
# positivo    238
# Name: sentimiento, dtype: int64

# %%
df.to_csv('df_final.csv')

# %%
positivos = df[df['sentimiento'].str.contains('positivo') == True]
negativo = df[df['sentimiento'].str.contains('negativo') == True]

# %%
compromisos = positivos[positivos['AGENDAMIENTO_ESTADO'].str.contains('COMPROMISO') == True]

# %%
compromisos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67 entries, 32 to 964
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   level_0               67 non-null     int64
#  1   index                 67 non-null     int64
#  2   ID_MOPC               67 non-null     float64
#  3   IDMOROSO              67 non-null     object
#  4   IDCLIENTE             67 non-null     object
#  5   OPERADOR              67 non-null     float64
#  6   CAMPAÑA               67 non-null     float64
#  7   IDGRABACION           67 non-null     object
#  8   TIPO_DISCADOR         67 non-null     object
#  9   FECHA                 67 non-null     object
#  10  ID                    67 non-null     object
#  11  IDLLAMADA             67 non-null     float64
#  12  ESTADO                67 non-null     object
#  13  SUBESTADO             67 non-null     object
#  14  F_INICIO              67 non-null     object
#  15  ANI_TELEFONO          67 non-null     float64
#  16  GRABACION_DEP         67 non-null     object
#  17  TIPO                  67 non-null     object
#  18  CRM                   67 non-null     float64
#  19  BASE                  67 non-null     float64
#  20  LOG                   67 non-null     object
#  21  DIRECCION             67 non-null     object
#  22  IDOPERADOR            50 non-null     object
#  23  AGENDAMIENTO_ESTADO   67 non-null     object
#  24  anos                  67 non-null     float64
#  25  mes                   67 non-null     float64
#  26  transcripcion_limpia  67 non-null     object
#  27  Contestador           67 non-null     float64
#  28  transcripcion         67 non-null     object
#  29  Valida                67 non-null     object
#  30  turnos_tokenizados    67 non-null     object
#  31  turnos_filtrados      67 non-null     object
#  32  turnos_lematizados    67 non-null     object
#  33  longitud_turnos       67 non-null     int64
#  34  frases                67 non-null     object
#  35  sentimiento           67 non-null     object
# dtypes: float64(10), int64(3), object(23)
# memory usage: 19.4+ KB

# %%
positivos.to_csv('positivos.csv')
from google.colab import files
files.download('/content/positivos.csv')

# %%
negativo.to_csv('negativo.csv')
from google.colab import files
files.download('/content/negativo.csv')
