# %%
# !pip uninstall nltk
# !pip install nltk==3.5
# !pip install rake-nltk
# Out:
# Found existing installation: nltk 3.7
# Uninstalling nltk-3.7:
#   Would remove:
#     /usr/local/bin/nltk
#     /usr/local/lib/python3.8/dist-packages/nltk-3.7.dist-info/*
#     /usr/local/lib/python3.8/dist-packages/nltk/*
# Proceed (Y/n)? y
#   Successfully uninstalled nltk-3.7
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nltk==3.5
#   Downloading nltk-3.5.zip (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 28.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk==3.5) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk==3.5) (1.2.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from nltk==3.5) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk==3.5) (4.64.1)
# Building wheels for collected packages: nltk
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.5-py3-none-any.whl size=1434691 sha256=34cf23606b655c13102ca379f1849db867dbab9c62a82a92107b1285a2327f32
#   Stored in directory: /root/.cache/pip/wheels/ff/d5/7b/f1fb4e1e1603b2f01c2424dd60fbcc50c12ef918bafc44b155
# Successfully built nltk
# Installing collected packages: nltk
# Successfully installed nltk-3.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rake-nltk
#   Downloading rake_nltk-1.0.6-py3-none-any.whl (9.1 kB)
# Collecting nltk<4.0.0,>=3.6.2
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 28.7 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (4.64.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (1.2.0)
# Installing collected packages: nltk, rake-nltk
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.5
#     Uninstalling nltk-3.5:
#       Successfully uninstalled nltk-3.5
# Successfully installed nltk-3.8.1 rake-nltk-1.0.6

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.cluster.util import cosine_distance
from sklearn.decomposition import LatentDirichletAllocation
import scipy.sparse
from rake_nltk import Rake
import numpy as np
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.probability import FreqDist
import re
import collections
nltk.download('punkt');
nltk.download('stopwords');
nltk.download('vader_lexicon');
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
df = pd.read_csv('transcripciones_para_modelo.csv')

# %%
compromiso = df[df['AGENDAMIENTO_ESTADO'].str.contains('COMPROMISO') == True]

# %%
compromiso.drop(columns='level_0', inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
compromiso.reset_index(inplace=True)

# %%
compromiso.columns
# Out:
# Index(['Unnamed: 0', 'level_0', 'index', 'Unnamed: 0.1', 'ID_MOPC', 'IDMOROSO',
#        'IDCLIENTE', 'OPERADOR', 'CAMPAÑA', 'IDGRABACION', 'TIPO_DISCADOR',
#        'FECHA', 'ID', 'IDLLAMADA', 'ESTADO', 'SUBESTADO', 'F_INICIO',
#        'ANI_TELEFONO', 'GRABACION_DEP', 'TIPO', 'CRM', 'BASE', 'LOG',
#        'DIRECCION', 'IDOPERADOR', 'AGENDAMIENTO_ESTADO', 'anos', 'mes',
#        'transcripcion', 'transcripcion_limpia', 'Contestador'],
#       dtype='object')

# %%
compromiso['frases'] = None
# Out:
# <ipython-input-8-7853df584320>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   compromiso['frases'] = None

# %%
for n in range(len(compromiso)):
  compromiso['frases'][n] = re.split(r'\s{2,}', compromiso.transcripcion_limpia[n])
# Out:
# <ipython-input-9-8a683c20db57>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   compromiso['frases'][n] = re.split(r'\s{2,}', compromiso.transcripcion_limpia[n])

# %%
type(compromiso['frases'][3])
# Out:
# list

# %%
len(compromiso)
# Out:
# 468

# %%
# import pandas as pd
# import re
# import random

# def seleccionar_frases(df):
#     # Crea una lista vacía para almacenar las frases seleccionadas
#     frases_seleccionadas = []

#     # Accede a la columna de transcripciones
#     transcripciones = df['transcripcion_limpia']

#     # Recorre cada transcripción
#     for transcripcion in transcripciones:
#         # Busca un patrón en la transcripción
#         match = re.search(r'monto', transcripcion)
#         if match:
#             # Divide la transcripción en frases
#             phrases = re.split(r'\s{2,}', transcripcion)
#             # Selecciona una frase al azar
#             selected_phrase = random.choice(phrases)
#             # Añade la frase seleccionada a la lista
#             frases_seleccionadas.append(selected_phrase)

#     # Devuelve la lista de frases seleccionadas
#     return frases_seleccionadas

# %%
# # import pandas as pd
# from collections import Counter
# from nltk.tokenize import word_tokenize

# # # Carga el dataframe
# # df = pd.read_csv('transcripciones.csv')

# # Itera sobre cada fila del dataframe
# for index, row in compromiso.iterrows():
#   # Extrae la lista de frases de la fila
#   frases = row['frases']
  
#   # Tokeniza cada frase y crea una lista de todas las palabras
#   palabras = []
#   for frase in frases:
#     palabras += word_tokenize(frase)
  
#   # Calcula la frecuencia de cada palabra
#   frecuencia = Counter(palabras)
  
#   # Selecciona las palabras más frecuentes como posibles temas en común
#   temas = [palabra for palabra, count in frecuencia.most_common(5)]
  
#   # Extrae las frases que contengan las palabras seleccionadas
#   frases_tema = []
#   for frase in frases:
#     if any(tema in frase for tema in temas):
#       frases_tema.append(frase)
      
#   # Imprime las frases relacionadas con el tema
#   print(f'Temas en común para la fila {index}: {temas}')
#   print(f'Frases relacionadas: {frases_tema}')

# %%
temas = ['pago',
 'deuda',
 'cuotas',
 'pesos',
 'whatsapp',
 'pagar',
 'hoy',
 'telefono',
 'cuenta',
 'momento',
 'saldo',
 'llamar',
 'nombre',
 'habla',
 'tarjeta',
 'hablo',
]
# Itera sobre cada tema
for tema in temas:
  # Lista de frases por tema
  frases_tema = []
  
  # Itera sobre cada fila del dataframe
  for index, row in compromiso.iterrows():
    # Extrae la lista de frases de la fila
    frases = row['frases']
    
    # Itera sobre cada frase
    for frase in frases:
      # Comprueba si la frase contiene el tema actual
      if tema in frase:
        # Añade la frase a la lista de frases por tema
        frases_tema.append(frase)
        break
        
  # Imprime la lista de frases por tema
  print(f'Frases relacionadas con el tema {tema}: {frases_tema}')
# Out:
# Frases relacionadas con el tema pago: ['el pago tiene que estar antes del mediodia si', 'si senor como verifico que usted ya pago la deuda entonces estaria quedando con el', 'que yo siempre tenia voluntad de pago', 'ah bueno si quieren enviarlo de vuelta para tenerlo mas fresco pero apenas me depositen voy y les pago', 'lo recuerdo y siempre pago un poquito de esto despues', 'eso te queria decir porque ella pago', 'para cuando podriamos agendar otra vez su pago', 'mientras yo espero el pago la acreditacion del pago de ayer si', 'y si usted esta autorizada para cerrar un acuerdo de pago', 'o no se o cupones para pagar en un rojo y pago o la cuenta para hacer la transferencia', 'la primera es obviamente por pago al contado', 'no me dieron los datos del estudio para que abone por un pago facil', 'por el pago del banco frances del dia de hoy', 'o mercado pago tambien puede ir directamente al banco santander rio nosotros le mandamos', 'realizado el plan de pago', 'el primer pago tiene que estar a mas tardar del dia viernes', 'si el pago usted lo usted lo prefiere irse al banco a bonar o lo hace por transferencia', 'pudo realizar el pago que se habia comprometido a abonar', 'lo llamo porque le habia enviado el mail con la propuesta de pago no se si lo pudo chequear', 'y a quien cuenta con la posibilidad de poder ir en contra de la duda y revisando a pago', 'visto la que la cancelo he echado y no le pago mas', 'sea enviado a legales y se inician las acciones correspondientes por incumplimiento de pago', 'todo bien queria confirmar con ustedes tamara si pudieron efectuar el pago de la ultima cuota de la tarjeta corporativa', 'lo que le voy a pedir es que el primer pago sea lo antes posible para hacerlo en cuotas', 'como hacer el pago por transferencia', 'preferente el compromiso de pago que dejamos asentado con un companero quisiera saber si ya abono la primera cuota', 'el banco no se si le informaron el saldo total las posibilidades de pago', 'si nada mas para recordarle el compromiso de pago para el dia de hoy', 'en un pago el banco se lo deja en', 'pagos a cuenta cargamos un pago a cuenta de', 'porque no hemos recibido a auto comprobante de pago y la cuota esta vencida cuando se esta reclamando los', 'de los de la manera de pago en nuestras clientes nosotros tenemos la opcion de facilitar', 'es lo que usted sabe si hay plan de pago', 'cuando nos desciaban estan ahi en el cajero en el pago ufar si no en el rato no no', 'lo pago antes asi ya estar un cosa terminado', 'opcion ya tendriamos que ir por un plan de pago comenteme su situacion a la fecha', 'yo voluntad de pago tengo', 'pero bueno para aclararle usted lo que tiene que hacer es el pago del anticipo de', 'he recibido en el dia de hoy el mail si con el pago', 'si yo me estaba comunicando para recordarle de su pago senor miel', 'en este caso nosotros lo que hacemos es una refinanciacion o ver a un convenio de pagos', 'el compromiso de pago con el banco santander', 'queriamos bueno en realidad saber bien de cuanto era la deuda que tiene y al ver alguna forma de pago', 'pero a partir del mes de julio abonaria ese dinero el primero es el pago de la anticipacion', 'eh nos estamos comunicando porque bueno tanto tenemos todavia el pago que habiamos acordado', 'puedo realizar tu pago al dia de hoy jorge', 'entonces le pido por favor que me haga llegar el comprobante de pago', 'y vamos a ver cual es el ultimo pago informado', 'y el pago se impacta directamente si', 'buenos dias jose me contas esto por el pago pendiente que tiene con fecha', 'pesos en un pago', 'ese pago te van a estar permitiendo refinanciar por ejemplo ya te informo cual seria el', 'para que pueda cancelar en un solo pago con menos dinero', 'o a traves de mercado pago', 'algun plan de pago para regularizar su situacion con el banco es solo saber que esta malo', 'si no lamentablemente la tengo que pasar como negativa de pago si no tengo el pago para esa fecha lamentablemente lo tengo que pasar directamente como negativ ...
# Frases relacionadas con el tema deuda: ['bien la deuda que presenta el dia de la fecha son', 'si senor como verifico que usted ya pago la deuda entonces estaria quedando con el', 'que se enteraron de que tenia la deuda que tenia con ustedes', 'si necesitaria saber que me confirme hoy si va a pagar o no la deuda porque el banco medrio suele bajos', 'la deuda que presenta a usted o su esposo es del santander o del banco frances', 'se puede cancelar hasta en la mitad de la deuda', 'si es referente a la deuda que tiene con el banco santanderrio', 'que le mando primero que le tengo que informar la deuda actual y las opciones despues si', 'habla barbara de la agencia mopc por la deuda con el banco santander rio', 'que tal le hablo de la agencia de cobranza cmypc por una deuda que el mantiene con bdva', 'si senor daniel lo estoy llamando por la deuda que vencio en junio del', 'meupc hablamos la semana pasada con respecto a lo que es la deuda con bbva', 'si betina la contacto por el tema de la deuda', 'si si y libre de deuda me van a enviar lo es por que va eso', 'no sabe para nada si es gordillo favor comunicarse de manera urgente al estudio juridico moipc por la deuda con el banco santander rio al', 'que tal rolando me estoy contactando de la agencia de cobranzas moipc por la deuda que mantiene con bbuva', 'por la deuda que el mantiene con bancobbva', 'que tal me estoy contactando de la agencia mpc una deuda con bajo frances norma', 'por la deuda del bba frances', 'de la agencia de cobranza cmo y pc por una deuda que rocio mantiene con el banco vdwa', 'de acuerdo yo me queria comunicar bueno con usted por una situacion de una deuda que tiene con el banco', 'el monto de su deuda', 'que hayas pagado y a los que te queda de la deuda total con intereses y con todos que yo ya te conte que era de', 'nos comunicamos de mpc collection por la deuda de banco frances', 'la una consulta maria al dia de hoy solamente monto esta su deuda', 'llamado es para hablar sobre la deuda que tiene activa la realidad de la fecha con', 'un gusto como le va me estoy comunicando del estudio juridico m o ipc referente a la deuda del banco san sander', 'no tengo manera de pagar la deuda ahora', 'senor leonardo lo llamo por la deuda que menciono en abril del', 'es referente a la deuda que tiene hasta la fecha con el banco santanderrio senor leonardo', 'la deuda me dijo pero despues', 'de la agencia de cobranza cme opc collection por la deuda con el banco abbva', 'le da un total de deuda de', 'lo estoy llamando porque recibio un mail de su parte en el cual usted detalla que supuestamente no tiene deuda asi que tiene todas las deudas al dia', 'obviamente no quiero dejar la deuda y eso', 'recuerda me estoy comunicando por la deuda de bbva', 'en este caso lo llamamos por la deuda actual con tarjeta de credito visa y prestamos', 'si es referente belen levesma la saluda referente a la deuda que dejamos asentado', 'queriamos bueno en realidad saber bien de cuanto era la deuda que tiene y al ver alguna forma de pago', 'banco frances con una deuda de doscientos cuarenta y dos mil pesos yo queria saber', 'lo llamo de vuelta a jorge por la deuda del banco santander rio', 'ir al banco nosotros no tenemos el detalle nos pasan la deuda nada mas', 'meopc por deuda del banco frances', 'por la deuda de banco frances', 'pero para yo si yo lo pago yo tengo que transmitirle el libre deuda al veraz', 'de como un cereces o una deuda', 'en contacto de la agencia de cobranza semeo peseco elexon por tu deuda con el banco', 'yo me queria comunicar con usted por una situacion pendiente que tiene con el banco por una deuda', 'no tenia deuda', 'una estafa por una deuda con un estudio juridico en el cual pague y resulta que el banco nunca', 'ah buen dia como le va a afluenciar la senora maria rosa de la agencia de miopc por la deuda del banco frances como estas tu', 'la esta llamando la senora maria rosa de la agencia de meopece por la deuda del', 'porque en realidad mi deuda eran no se', 'la ...
# Frases relacionadas con el tema cuotas: ['las cuotas', 'despues se puede hacer en cuotas con menos quita', 'en tres cuotas bueno de hecho senor si es que usted me confirma', 'bueno la de tres yo te pase lo que pasamos siempre tres cuotas iguales', 'el tema es que el banco le da la posibilidad de hacer cuotas', 'si tienen algun plan de caso que el minimo de cuotas son', 'no pero no todo no tengo para pagar solo no puedo hacer en dos o en tres cuotas', 'y yo digo bueno pues eso es lo que pago dos cuotas juntas se puede pagar dos cuotas juntas', 'o en dos cuotas manteniendo el descuento de', 'hasta en dos cuotas de', 'a decir que no completaste las cuotas lo que puedo hacer es pedirla solicitar al', 'este que el importe total es tanto y sesenta por ciento y es las cuotas y pasame la propuesta', 'son cuatro cuotas', 'despues donde cuotas a vencer en mayo en junio y los meses posteriores eso iba a tener', 'que en realidad usted tenia deudas y de hecho sobre este saldo que usted tenia pendiente nosotros le habiamos cerrado dos cuotas para que lo paguen', 'cuotas', 'esto se lo dejo como que lo cancelan dos cuotas con las dudas', 'y si me pueden quedar mas una de las cuotas mas chicas me entendes a ver yo queria', 'lo que puede hacer entonces es un plan de seis cuotas', 'con todas las cuotas proximas a vencer tambien que tenia', 'le puedo dar dos cuotas para que lo pague y que lo pague en dos veces', 'algun descuento si tienes la posibilidad de cancelar en un pavo o en dos cuotas si', 'ademas bueno a ver con nosotros lo puede solucionar en un cuotas o es mas', 'y si la hacen cuotas es el valor de la cuota ahi ya no tiene descuento', 'y si yo tengo conmemorada en los zapatos de las cuotas', 'bueno podes tratar de ver si podes armar un plan de cuotas o tratar de llegar a las', 'se puede hacer una financiacion en cuotas', 'por lo que quiero ofrecerle un descuento y pagar en cuotas', 'cuotas de', 'cuotas', 'cuotas de', 'lo cancelaria en tres cuotas de', 'o lo pueda bonar en tres cuotas de', 'en este caso las cuotas serian fijas sin ningun tipo de interes y abonaria una cuota por mes', 'en tres cuotas ya estarian los', 'saltar en un pago le puedo ofrecer un plan en cuotas no me gustaria hacerlo solamente en un pago', 'y en cuantas cuotas', 'y la una consulta usted habia arreglado con alguna quita o eras simplemente cuotas recuerdas', 'esto que es la refinancia en cuotas que van de', 'les llamo justamente para ofrecerle una quita quizas como para que pueda estar cancelando cuotas', 'la llamo justamente para poder acordar cuotas o una quita de ser necesaria', 'le puedo ofrecer a abonarlo en tres cuotas sin interes de', 'puede cancelar en tres cuotas sin interes de', 'y despues la ot quiere cancelar en un pago y no le paso el plan en cuotas', 'de descuento en cuotas', 'dos cuotas de', 'pero hasta en dos cuotas de cuatro mil cuatro mil cuatrocientos pesos', 'la primera que se ha contado y la segunda que es en cuotas', 'disculpe a las tres cuotas de', 'es dos pagos o tres cuotas si', 'cuotas del', 'y que esto lo pueda cancelar en tres cuotas sin interes de', 'abone en cuatro cuotas de', 'serian dos cuotas de tres mil', 'cuotas de o sea dice', 'me tenian que brindar la cantidad de cuotas y el monto', 'vale en el acuerdo que te hice son tres cuotas de nueve mil vos tendrias que estar pagando', 'no de ninguna manera ese monto no si queres en cuotas y arreglar unas cuotas si pero no tengo esa plata', 'cuotas de', 'cuotas', 'un caso para hacerlo en muchas cuotas a eso me refiero', 'cuotas que seria le indico cuatro mil cincuenta y seis exactamente', 'cancelaban cuatro cuotas de', 'o se le puede armar un plan de pago de tres cuotas', 'bueno esperemos un segundo que le paso un plan de cuotas en todo el mundo', 'a un maximo de tres cuotas', 'abonando de tres cuotas surge algo y por dos meses no pudo abonar obviamente el plan', 'en tres cuotas tres cuotas de', 'vamos a hacer un adelanto mas bajo o sea de menor valor y las cuotas tambien de menor', 'cuot ...
# Frases relacionadas con el tema pesos: ['pesos', 'pesos si tengo que hacerle nuevamente un plan de paos', 'pesos', 'pesos con', 'si senora soy yo ayer ya se le depositaron otros cinco mil pesos si', 'pesos la deuda que se tiene de', 'pesos lo que debe cancelar para llevar su libre de deuda senor daniel', 'pesos', 'pesos lo que yo le comento seria', 'pesos lo prefiero en un descuento tambien', 'pesos si', 'pesos', 'pesos', 'pesos', 'pesos que debiste pagar del humor', 'seiscientos noventa y nueve pesos con el descuento si noventa y dos mil seiscientos', 'pesos', 'todo y yo empece pagando seis mil pesos eh pague no se si una o dos veces los seis', 'pesos', 'pesos con', 'pesos porque esta sumando los', 'pesos yo lo escucho o sea', 'pesos recuerda', 'banco frances con una deuda de doscientos cuarenta y dos mil pesos yo queria saber', 'pesos y necesito que lo haga', 'aca lo tengo si cancela con cinco mil cien pesos le puse el dia', 'pesos', 'pesos', 'pesos', 'pesos con', 'y despues me aparecieron con un choclo que estaba bebiendo como cinco mil pesos', 'pesos', 'pesos con', 'pesos', 'pesos y todo', 'pesos', 'pesos se le habia ofrecido una cancelacion en un pago con descuento que', 'pesos', 'mil pesos si ese con el gasto de estudio todo por ejemplo', 'pesos', 'pesos con', 'pesos de honorarios', 'pesos por mes', 'pesos verifico que se ha un acuerdo anteriormente', 'pesos si', 'pesos', 'pesos en', 'pesos si si ese es el', 'pesos si', 'pesos', 'pesos que se', 'en relacion al caldo de su tarjeta de credito de seis mil ciento noventa y cinco pesos', 'cuenta corriente en pesos', 'mil pesos', 'pesos', 'pesos con', 'pesos todavia no fui porque no sali de casa', 'pesos digame senor gustavo tu algun inconveniente', 'un cincuenta y cuatro mil doscientos noventa y nueve pesos', 'pesos', 'si por un importe total de cuatro mil pesos hasta la fecha del dia de hoy', 'pesos', 'pesos de tarjeta visa mas honorarios que', 'pesos', 'pesos la totalidad', 'pesos si', 'pesos al dia de hoy', 'pesos al dia de hoy', 'pesos', 'pesos con el banco santander', 'pesos pero que en ningun mes te llegan los resumenes', 'pesos lo que yo lo ofrecen', 'pesos', 'pesos', 'pesos', 'pesos', 'pesos', 'pesos para cancelar deuda', 'pesos al dia de la fecha si', 'pesos senor', 'pesos', 'el importe total de ocho mil setecientos pesos', 'pesos', 'pesos la deuda que tiene en este momento', 'pesos y quiero llegar a una cuerda con usted para cancelar eso', 'pesos', 'pesos si', 'pesos', 'pesos', 'pesos no lo voy junta', 'pesos para hacer efectivo el primer pago para el dia de lunes', 'pesos', 'pesos', 'pesos porque le dices de', 'pesos con eso cancelaria y quedarian', 'y pico de pesos yo no tengo ningun comprobante ahora en mano porque la verdad', 'pesos de deuda es de', 'del banco del banco copesoso', 'pesos esa es la de', 'en su caso recorregiendo una cuota de dos mil ciento cincuenta pesos', 'pesos', 'pesos', 'pesos queriamos confirmar su pago para el dia de hoy', 'pesos', 'pesos senor lucas al dia de hoy con interes', 'mil pesos', 'pesos con', 'pesos nos preferiamos querremos', 'pesos luis asi como habiamos acordado', 'pesos', 'en cuenta ahi te voy a pedir tipo de cuenta cuenta corriente moneda pesos sucursal', 'pesos', 'pesos', 'pesos', 'pesos', 'pesos', 'pesos y despues hacemos', 'pesos diego adana', 'pesos queriamos confirmar si hay', 'pesos que habiamos acordado para poder pagar', 'pesos a la fecha', 'millones de pesos que me estan pidiendo', 'pesos', 'mil pesos al contado haz convencimiento hasta el', 'le repito seria mil quinientos setenta pesos una vez que el paga usted tiene', 'pesos', 'pesos', 'pesos menos es como un monton', 'pesos', 'pesos si', 'anos que no use la tarjeta tres anos supuestamente tenia yo doscientos pesos de gastos anuales', 'pesos y el banco le otorgo un descuento al', 'bueno cinco mil cuatrocientos pesos es la deuda total', 'pesos', 'pesos si', 'pesos si', 'hay un pago de nueve mil pesos el doce del cinco', 'pesos queriamos ver si podiamos negociar',  ...
# Frases relacionadas con el tema whatsapp: ['yo le voy a enviar tiene whatsapp en este numero', 'nosotros tenemos el contacto por whatsapp', 'igual tengo tu whatsapp asi que yo apenas deposito te mando un mensaje para que ya sepas', 'via whatsapp esta bien perfecto bueno senor le facilito entonces via whatsapp los datos si', 'igual le puedo mandar la informacion por whatsapp', 'no se que pero me llamaba hasta los domingos me llamaba por whatsapp', 'perfecto ahora hice la espera de whatsapp', 'usted tiene para hacer transferencia entonces yo le paso todos los datos por whatsapp o prefiere', 'yo ahora le voy a mandar toda la informacion por whatsapp', 'al whatsapp de ella si bueno bueno ahora limite gracias hasta luego', 'llame un monton de veces nadie me atendio escribi al whatsapp tampoco nadie me contesto', 'te mando este numero de whatsapp en comprobante vale', 'en el dia de manana le voy a enviar la informacion a traves de whatsapp tanto de la deuda como', 'le paso el whatsapp', 'me gusta whatsapp en este numero que hablamos', 'de mazo a este whatsapp estudio mvccollectionnito', 'los datos via whatsapp o via correo electronico ya dependiendo de como usted les sea mas', 'igualmente le voy a enviar por whatsapp', 'obviamente ustedes puedan destinar todos los meses si si igual si usted tiene whatsapp', 'se lo puedo pasar por whatsapp por donde le mandamos el contacto en el dia el dia', 'entonces llame al numero no de whatsapp chardo', 'le voy a pasar la propuesta de whatsapp por mediante whatsapp le va a quedar le vuelvo', 'ah se la mande yo por whatsapp en realidad porque no teniamos cacilla de correo', 'yo le mando directamente por whatsapp para que tenga mi contacto en caso que usted se quiera comunicar', 'pienselo y me envio un mensaje via whatsapp', 'ok me podes como andar igual al whatsapp pero', 'la estaba llamando para que era mas facil que explicar todo por whatsapp', 'tienes whatsapp vos ahora en este telefono', 'si quiere le dejo mi telefono o si usted tiene whatsapp en este telefono', 'via whatsapp los numeros de cuenta si', 'no la pudo volver a contactar no le envio a ella ningun whatsapp nada para contactarse', 'bueno espero que me mande el whatsapp y mandeme un whatsapp y asi ya directamente me avisa', 'si quiere le envio la informacion a traves de whatsapp y en el caso de que bueno pueda conseguir trabajo o algun sustento economico', 'ya le mando un whatsapp', 'ahi se lo voy a enviar por whatsapp', 'usted me mando un whatsapp recien', 'ah ok quiere que le mande las propuestas por whatsapp y usted las analiza y me contesta', 'no bueno asi que bueno se te paso todo rocio por el whatsapp y vos me cualquier', 'no le dejo un whatsapp para que no se escriba', 'hoy si falta que puedo devolverla llamada a yo al numero que me mandaste whatsapp', 'entonces lo que voy a hacer en este momento marcelo como le explico nuevamente voy a enviarle los datos al whatsapp', 'me mandan un whatsapp', 'enviado un whatsapp desde mi telefono laboral para que usted me agende y cualquier cosa me', 'bueno le voy a mandar un whatsapp le voy a mandar un whatsapp le pido que manana se contacte con el hombre', 'usted tiene whatsapp en este telefono', 'bueno si no le envio un whatsapp', 'nosotros le enviamos los datos a usted por correo electronico o por whatsapp y una vez', 'vos me lo podes tambien reenviar a mi whatsapp', 'pero no todavia no accedia al whatsapp por eso llamaba para verificar bueno apenas', 'numero de whatsapp que tengan entonces en ese mismo numero le envio los datos', 'sacanle una foto al ticket y mandalo por whatsapp', 'si es tan amable que me haga llegar el comprobar de una vez realizado no se si tiene whatsapp', 'transferirtelo bueno perfecto quiere que lo envie la info a traves de whatsapp o vma si por favor', 'y saldaba despues cuando comence a mandarme no me contestaban los whatsapp tampoco', 'a ver si quiere envieme igualmente lo que son los comprobantes ahora por whatsapp yo le envio asi me lo puedo reenviar igualment ...
# Frases relacionadas con el tema pagar: ['perfecto pero lo puedo pagar el martes que viene', 'si si era la unica tarjeta no por falta de pagar la tarjeta', 'si necesitaria saber que me confirme hoy si va a pagar o no la deuda porque el banco medrio suele bajos', 'por la semana que viene se lo voy a pagar gracias por llamarme y te pido disculpas', 'claro que ayer se pagaron cinco mil mas bueno quedaban catorce mil trescientos sesenta y cuatro con once', 'o no se o cupones para pagar en un rojo y pago o la cuenta para hacer la transferencia', 'pagaria', 'bueno despues me tendria que dar para pagar el', 'oh dios mio si justo ahora me voy a apagar porque usted tiene una nina', 'si pero que pasa porque en realidad se iba a pagar la mitad', 'hoy por hoy no puede pagar absolutamente nada', 'porque si se la deuda yo tendria que pagar', 'usted deje de pagar en noviembre y en diciembre ya no tenia la deuda al banco frances', 'mira que es un estudio que tengo que pagar que yo reconozco la deuda', 'y yo digo bueno pues eso es lo que pago dos cuotas juntas se puede pagar dos cuotas juntas', 'si si que ya fui cuando quise pagar todo junto a un mujer al pez', 'no tengo manera de pagar la deuda ahora', 'pagos esas quitas estan siempre vigentes lo que urge si es que este mes empiece a pagar', 'pesos que debiste pagar del humor', 'yo tengo tiempo de pagar esto en la primera cuota te digo senor seria hasta el viernes', 'cuanto me dan a pagar porque', 'y si la uso y ahora no se puede pagar pero bueno lo ideal es que bueno intente', 'cobro es mopc collection para que no tenga que hacerse el viaje para pagar usted paga', 'yo no tengo ningun problema pagarlo', 'bueno yo me intersione pagar', 'bueno teniamos que pagar el', 'si en una de esas campanas me vas a pagar manana', 'la gestion de que somos el plazo de banco y usted se quede tranquilo de donde va a pagar', 'la intencion de pagar de que pero cuentenme un poco mas por que esta complicado', 'para atencion a proveedores enviad mail a cuentasapagararrobacimacomar o aguarde y', 'no es imposible pagar', 'decidme en donde lo tengo que pagar', 'bueno entonces vos me podias mandar algo al sat lo que tengo que pagar y actualizado', 'a cobrar no me voy a pagar', 'independiendo obviamente la posibilidad que tengas ahora de comenzar a pagar', 'claro pero hace como dos meses que me esta diciendo toda la semana cuando va a pagar por que necesito pasarlo al banco', 'tengo que pasar los datos del pago los datos de la cuenta si no lo voy a poder pagar', 'que pasa si yo logro pagar la que quito y me hacen de pagar la toda', 'no en este momento hoy no tenia que ver en estos dias como puedo hacer para poder pagarlo', 'si si si porque la voy a pagar pero ahora es justo tambien de trabajo', 'o sea que es lo que deberia pagar primero como para saber no tener tanto lio al momento del pagar todo', 'pagarla pero bueno no se como se puede hacer porque yo ahora estoy sin trabajo digamos', 'y al dia de hoy si se cuenta de pagar un', 'o si no se los saco ahora y le digo cual es la bonificacion que hay para pagar', 'por lo que quiero ofrecerle un descuento y pagar en cuotas', 'por eso mira en realidad se me encantaria tener todo como para pagar de todos juntos', 'tenemos que agradecer que se van a pagar', 'no tiene ninguna va a pagar manana o a estirar un mes', 'estoy muy convocada por apagarlo', 'si el banco no va a respetar el acuerdo y vas a pagar la quita que te precisa del', 'no por eso estoy tratando de pagar', 'usted me mando un correo y me dijo si no se puede pagar hasta el treinta volvemos a', 'si si si porque no no no es el tema de no pagar la duece pues solo el pago lo', 'ir ahi a pagarlo desde mi transferencia no se por que', 'como hago yo para pagar eso que dicen que yo debo', 'mil pesos pero tiene que pagar en un pago', 'le quedaria a pagar para que tengan cuenta de', 'pero ustedes saben que yo no tengo el trabajo como si decidi lo voy a pagar o les voy a', 'pero todavia me pagaron sin hacer', 'sin trabajo entie ...
# Frases relacionadas con el tema hoy: ['hoy desde poder informar', 'en estos dias tiene que ser lo te digo porque por ahi hoy o por ahi manana porque por ahi es pasado', 'si necesitaria saber que me confirme hoy si va a pagar o no la deuda porque el banco medrio suele bajos', 'y esa es su deuda a hoy porque', 'diferente por esto que yo le comente hoy mas temprano', 'por el pago del banco frances del dia de hoy', 'esto puede abonarlo para el dia de hoy o manana', 'y quedamos que hoy nos juntamos asi vemos como hacemos y yo les mando mensajes hoy a la tarde', 'por eso yo tengo que cerrar hoy una negociacion con usted', 'hoy por hoy no puede pagar absolutamente nada', 'y que salga esta situacion negativa que hoy presenta', 'la una consulta maria al dia de hoy solamente monto esta su deuda', 'esto es lo que debe hoy al banco de la refinanciacion si', 'si nada mas para recordarle el compromiso de pago para el dia de hoy', 'si ayer llamo y hoy tambien se me corto', 'en este caso el total que nosotros nos derivan hoy al dia martes sobre los dos productos', 'cada banco si es decir a usted le pueden otorgar hoy una tarjeta de credito con alguna', 'se le puedo mandar al mail a el cual me hablo hoy', 'y eso yo pago eso hoy y dentro de', 'he recibido en el dia de hoy el mail si con el pago', 'pero que tendria que abonar el dia de hoy', 'estoy ingresando al banco para decirles la deuda ajustada al dia de hoy si', 'y hoy el sueldo no es mucho y', 'puedo realizar tu pago al dia de hoy jorge', 'le pido por favor que apenas abona hoy la primera entonces', 'si no bueno hoy usted en el transcurso del dia', 'eso es lo que yo consegui para poder cancelarlo hoy o manana', 'eh no estare trabajando no tengo un ingreso fijo eso que hoy no tengo un sol no fijo', 'hoy', 'de hoy ninguna', 'aqui lo lo puedo encontrar y hoy mas o menos despues de las', 'a ver el saldo al dia de hoy esta en', 'mire a hoy la deuda es', 'al dia de hoy esta debiendo de una tarjeta master casi', 'hoy por hoy es un monton pero capaz que uno te presta una mitad la otra te presta', 'y al dia de hoy si se cuenta de pagar un', 'hoy si falta que puedo devolverla llamada a yo al numero que me mandaste whatsapp', 'excluso un sentimiento del que fue en hoy en este momento', 'entonces bueno o sea hoy le dije', 'de abril y hoy ya es', 'hoy o manana', 'la una consulta matrimiliano al dia de hoy saben que monto esta su beuda', 'no no el lunes no hoy el lunes es feriado', 'buen dia buen dia mire me comunico porque el dia de hoy', 'bien perfecto eugenia cuanto es lo que puede abonar en el dia de hoy', 'entonces hoy esta en esta agencia', 'usted en el dia de hoy puede avanzar con el pago de la primera cuota', 'bueno pero hoy podria ocuparse de hacer el deposito si yo cuento con el dinero', 'ah bien y en el dia de hoy no se puede acercar a bonar tampoco', 'diganme gustavo la primera cubota lo puede hacer para el dia de hoy o el dia de manana', 'banco pronto en caso de que reciba hoy', 'si por un importe total de cuatro mil pesos hasta la fecha del dia de hoy', 'la contacto por la deuda que tiene en la tarjeta visa al dia de hoy son', 'hasta el dia de hoy le deben dinero al pib me entiendes', 'pesos al dia de hoy', 'pesos al dia de hoy', 'al dia de hoy saben que monta esta su deuda', 'hasta hoy en dia no otorgare ningun libre de deuda por mail', 'como esta todo hoy', 'el dia de hoy o el dia lunes es solo para esto seguramente seguramente el lunes el', 'pesos esto puede usted pagarlo en un solo pago para hoy o manana ariel', 'por favor senor que no te olvide que hoy vence su cubota', 'ah bien en el dia de hoy', 'para el dia de hoy', 'usted puede hacer el esfuerzo de cancelar esto para hoy o manana', 'el dia de hoy mes le hemos enviado un mensaje', 'si exactamente el monto que iba hoy ha faltado', 'es lo que me esta figurando hasta el dia de hoy', 'queriamos confirmar su pago para el dia de hoy', 'si el deudor paga hoy y manda el comprobante dentro de', 'si por decirte si usted abona el dia de hoy  ...
# Frases relacionadas con el tema telefono: ['el telefono por ejemplo', 'este telefono se lo le dan a mi marido que tiene la tarjeta del banco frances', 'le puedo dejar un numero de telefono para que se comunique cuanto antes con nosotros', 'ah bueno pero bueno entonces por ahi no lo podemos contactar a sus telefonos antiguos', 'telefono para que podamos contactar con usted', 'si este es el telefono de la hora pero ellos estan trabajando desde la casa asi que no tengo el numero de ella esta hablando con el guardia', 'bueno cual tipo de ser me mandas el telefono me mandarme un cupon algo de eso', 'o un telefono', 'ella me llame varias veces y no atendio el telefono ahora le iba a enviar un mensaje', 'contacte la brevedad a su telefono', 'por favor le pido que urgente se comunique con nosotros al telefono', 'como voy a aconsejar que me llame por telefono', 'primero el telefono este no funciona bien', 'usted se llamo por telefono', 'el telefono de la agencia si para que usted llame el telefono es', 'a ver como me lo pasas por telefono como tiras', 'no porque me ha dejado este telefono como particular senora', 'se lo dije por telefono', 'por eso yo recoloque el numero de la agencia de cobranzas que es un telefono fijo', 'si me esperas dos minutos que te llamo el telefono de casa', 'puedo pagar yo hable con una chica ahi del cozo y que me dieron un numero de telefono ahi en', 'tienes whatsapp vos ahora en este telefono', 'si usted tiene nuestro telefono tiene para notar', 'nuevamente no porque perdi todos los numeros tuve un problema con mi telefono y perdi', 'bueno ahora yo lo tengo aca en el telefono te estoy atendiendo', 'te pido por favor que se comunique a la brevedad al telefono', 'mopc representando a american express necesito por favor que se comunique al telefono', 'eso acumula un telefono por dia', 'pero mandeme un whatsapp y yo la llamo por telefono y vemos a ver como lo que es lo que decidio', 'nuestro telefono es', 'pesame a ver pesame un numero de telefono a ver', 'por mi fue todo por el telefono', 'estoy usando un telefono en este momento', 'yo a este telefono que estoy llamando es un celular si el celular mio', 'bueno hasta el telefono me cortaron', 'o sea no puedo atender el telefono en el horario que lo llaman', 'en un telefono fijo no este es el unico que tengo no tengo fijo', 'donde te tenia que andar no lo tengo en este telefono', 'si senora recien me corto el telefono de la agencia de miope telepero un te por', 'usted tiene whatsapp en este telefono', 'y despues yo le dejo mi telefono y me llama y me dice como va a pagar la deuda', 'damos yo lo vuelvo a contactar o le voy a dejar mi telefono si tiene para', 'por favor repido que se contacte al telefono', 'ya hemos representado a los american express por favor contacte surgente al telefono', 'su gente a telefono', 'en el telefono recuerda tu mensaje', 'no no no tengo no porque tengo cortado el telefono ahora', 'no se yo pedi el telefono de mi hijo', 'a traves de whatsapp en este mismo telefono en este mismo telefono bien se sale caracteristica', 'porque si yo soy el papa ah el papa bien y en que telefono luico al senor salvo', 'yo la puedo ayudar dandole un numero de telefono', 'me tiene para notar nuestro telefono', 'si le doy nuestro telefono a angel', 'le puedo dejar un numero de telefono', 'te van a visitar tu casa esta en mopc te van a pasar nuestro telefono fijo', 'modificar o ver el telefono', 'es verdad que el telefono me iba a dar mal', 'como suelto te tiene whatsapp en este telefono', 'solicito por favor que se comunique por el pago de su dedo al telefono', 'por whatsapp el telefono', 'me llamaron por telefono', 'le voy a crear un whatsapp con el telefono del estudio', 'reclamo que yo el reclamo lo hice por telefono y vi a mi y vi a pagina y vi a todos si pero por telefono no le', 'usted tiene whatsapp en este telefono asi ya le paso la propuesta para que lo pueda leer bien eric', 'bueno si te contaste a los telefonos', 'no porque mi telefono como tu ll ...
# Frases relacionadas con el tema cuenta: ['ahorita la voy a agregar al whatsapp y le voy a pasar el numero de cuenta donde tiene que pagar', 'bueno senor para que tengan cuenta entonces el monto seria de', 'toman la decision de dar de baja la cuenta por estar en falta con otro banco', 'si se lo puede hacer antes cuenta', 'o no se o cupones para pagar en un rojo y pago o la cuenta para hacer la transferencia', 'cuenta le dieron', 'a usted su propio cbu de usted senor daniel para que haga el depositado en su cuenta', 'con eso la cuenta quedaria en', 'si le puedo esperar hasta el miercoles a mas tardar senor tomas porque necesitamos que abone antes de que pase alegale la cuenta', 'como para que usted lo tenga en cuenta si', 'y a quien cuenta con la posibilidad de poder ir en contra de la duda y revisando a pago', 'yo me quiero comunicar con celeste por una situacion pendiente que cuenta con el banco actualmente', 'si el companero diego es exactamente el que le esta haciendo el seguimiento a la cuenta de usted', 'y si esta interesado en pagar lo pagan en esa cuenta que le abrio el banco', 'o lo ir cuenta con la posibilidad', 'pagos a cuenta cargamos un pago a cuenta de', 'cumplimientos del obtener en anterior cero de baja por incumplimientos en cuenta que un segundo', 'y bueno y la cuenta donde estas que pago ok senor sin problemas le facilitamos', 'se le descuentan', 'esto se descuenta sobre el total y sale con firmo como le quedarian los planes', 'de eudado que corresponde a cuenta visa queria comentarle sobre los montos y las', 'no me van a meter cuentas que no debo', 'a ver tengan cuenta que seria distinta la situacion', 'y hay una posibilidad por ejemplo de que lo que me quede se esta en cuenta', 'la refinanciacion cuenta que solamente con un antisimpo del', 'y tiene que depositar a su cuenta para que ingrese', 'para atencion a proveedores enviad mail a cuentasapagararrobacimacomar o aguarde y', 'perdon es la misma cuenta', 'en la cuenta de la agencia que nosotros le pasamos', 'usted no cuenta entonces con el dinero para poder cancelarlo', 'como que se ve la gente de cuenta de la media', 'de tu cuenta si despues vas a tener un plan de', 'via whatsapp los numeros de cuenta si', 'y bueno entonces entre el viernes o el lunes yo me hago cargo de esa cuenta y le prostito el amor del compregante', 'tengo que pasar los datos del pago los datos de la cuenta si no lo voy a poder pagar', 'y realmente no se si podras mandarme algun detalle o algo de la cuenta', 'si el banco nos derivo su caso a la agencia porque hay una cuenta visa en mora', 'poder regularizar esto armar algun plan de cuenta si mi intencion si es obviamente', 'y al dia de hoy si se cuenta de pagar un', 'por el salva deudado de cuentavisa', 'bien quiero comentarle claudia que en la cuenta', 'pero pasame algo antes que diga yo tengo que transferir a este numero de cuenta para el pago o cancelacion del total de las deudas ok', 'o sea uno tiene que tomar todo en cuenta', 'cuenta que usted tenia con el banco para ver si podemos llegar a algun acuerdo', 'sigan cuenta que igualmente le paso a comentar que bueno como esta una estancia prejuicial', 'si el no esta en cuenta en ese momento con quien tengo el gusto', 'igual los resolvi pasandote otra cuenta', 'lo que debe la tarjeta de compras que es la terminada en mil tres debe cincuenta y', 'y si tengan cuenta de que hay que hacerlo lo antes posible porque lamentablemente la', 'el pago minimo mas atrasado y evita sumar intereses en la cuenta si', 'cuenta corriente en pesos', 'de cobranza cme opc collection en referencia a lo que corresponde al saldo de la cuenta', 'porque el dia de manana lo que necesita es si no le imprimen el ultimo resumen de cuenta', 'le quedaria a pagar para que tengan cuenta de', 'y me quedaron muchas cuentas para y no tengo como no tengo en realidad tengo con el auto', 'bien y si no hay alguna consulta por transferencia o por pago mis cuentas que puedas llegar a bonar', 'su cuenta el proximo mes la cuenta  ...
# Frases relacionadas con el tema momento: ['esta sin trabajar usted esta sin trabajar en este momento', 'si yo en este momento no puedo hablar', 'porque lo hacemos mal momento ahora', 'si igualmente esta propuesta ya me la habia nacio en otro momento y como usted estaba', 'uno uno seis ocho seis nueve cinco cuatro ocho uno no se encuentra disponible en este momento', 'de la tarde en ese momento no puedo', 'voy a ver un momento', 'si me voy a comunicar en este momento con la sucursal para ver cual fue el error si', 'yo le descuento las cuotas que hayas pagado y a lo que queda le aplico la quita vigente que en este momento es del', 'a ver ya es un momento que he quitado', 'en aquel momento estamos hablando ya hace unos anos', 'de momento cual es la situacion suya en este momento', 'le puedo aplicar la quita maxima que en este momento es el', 'me podras llamar en otro momento', 'dime un momento', 'prelegal nos figura que tiene un vehiculo usted ha su nombre no se si en su momento', 'cuando yo le habia explicado a usted en su momento a principios de este mes perdon a fines del mes pasado', 'cuando yo llegue ya estaba refinanciado y entonces directamente yo tome una decision en ese momento', 'no en este momento no se encuentra', 'y algo pero no recuerdo bien el momento', 'momento nosotros siempre estabamos bien por la extra que teniamos nunca ahora de la', 'no yo en el momento tengo', 'que no llego a cubrir el total que era el resumen de ese momento', 'abordamos un momento que ya te', 'perdi el contacto con la senora con la que estaba hablando en su momento', 'no no no el no se encuentra en que momento lo publicara', 'y no te encuentres con el electrico momento por favor', 'o sea en ningun momento cuando pedi de arreglar algo con el banco', 'no en este momento hoy no tenia que ver en estos dias como puedo hacer para poder pagarlo', 'o sea que es lo que deberia pagar primero como para saber no tener tanto lio al momento del pagar todo', 'situacion el banco en este momento esta ofreciendo planes que realmente en otro momento no los', 'que tiene en este momento', 'tres cinco uno seis siete nueve cuatro uno siete ocho no se envuelve el ponible en este momento', 'si te toco que estamos pasando no puedo en este momento lamentablemente', 'perfecto yo en este momento lo voy a enviar al mensaje marcelo para que haga el deposito y de esa manera cancelarla de nuevo', 'no mira eso sabe que yo no estoy sin trabajo y estoy un poco operatorio por el momento', 'excluso un sentimiento del que fue en hoy en este momento', 'ella me habia comentado que usted en este momento se encontraba sin empleo', 'lo que pasa es que yo en ese momento digamos', 'estoy usando un telefono en este momento', 'unene que momento', 'el total en ese momento no', 'si el no esta en cuenta en ese momento con quien tengo el gusto', 'perdon perdon hace el primer momento complicado con unas cosas aca y eso te pido mi disculpa', 'estamos obteniendo nada de este ultimo momento pero', 'mire en este momento no es que me voy a vaniar estoy almorzando si me llaman una hora la escucho', 'bien bien estoy tratando de hacerlo posible en este momento me estoy trabajando', 'ustedes estan en condiciones de poder pagar esto en este momento porque queremos llegar', 'y la fecha que seria para el veintitres en este momento estoy dejando asentado', 'las opciones de pago para que pueda regularizar perfecto bien aguardo un momento que ya le', 'no no tengo el telefono en este momento yo lo voy a tratar de ubicar y avisarle', 'podemos dejarlo para sentado para ese momento', 'estoy de frente jubilada no tengo esa plaza fui a pagarla en su momento', 'ariel en usted me dijo que esta esperando que el banco le de una respuesta usted hizo algun reclamo en su momento', 'de momento cual fue el motivo de mi atraso', 'pablo en este momento la deuda de ustedes esta en el area de ejecuticiar', 'en un momento le dieron tres cuotas con un', 'un momento por favor', 'pesos la deuda que tiene en este momento', 'no pen ...
# Frases relacionadas con el tema saldo: ['en relacion a su tarjeta de compras si si por el saldo pendiente en su tarjeta', 'con el saldo y top numero para que pueda autorizar', 'por este saldo bueno si va un embargo es mucho mas', 'yo me comunico referente a un saldo pendiente de', 'si le estoy llamando por el saldo', 'bueno le comento cual es el saldo y las opciones que tiene para cancelar su deuda', 'a ver le digo seria un maximo de tres cuotas para ya cancelar el tema de los acustes y solamente cancelar este saldo', 'si me comunico por el saldo pendiente a abonar', 'si es por el saldo del tribunal el banco queria ofrecerle un descuento para que pueda cancelarlo', 'el banco no se si le informaron el saldo total las posibilidades de pago', 'es por el saldo de udm', 'para julio en agosto tendriamos que elevar al banco vos y yo un convenio por el saldo a ese saldo', 'por eso es el saldo total', 'hemos recibido en la agencia el saldo de la tarjeta de credito visa y se sumo lo que', 'si es que corresponde a gasto de renovacion anual de tarjeta o le quedo algun saldo', 'que en realidad usted tenia deudas y de hecho sobre este saldo que usted tenia pendiente nosotros le habiamos cerrado dos cuotas para que lo paguen', 'bueno le paso el saldo actual que nos informa el banco a nosotros el importe actual a la', 'del saldo total lo', 'el saldo total es de', 'bueno lo llamo por el saldo pendiente que ya lo venimos hablando de los', 'de agonarlo haga lo posible porque asi se mantiene el saldo sino le va a actualizar el banco y le va a ingresar los nuevos intereses', 'me figura que saldo total es de', 'y es como que siempre me venia como un saldo', 'ya que es un saldo chico', 'de crisis sociedad anonima por el saldo', 'estudio mipc del banco santanderrio si si es por el saldo penente a un al el', 'yo veo aca que tiene un saldo que no es muy alto', 'la verdad es que a mi lo que me figura es que eso era saldo vencido', 'si ya mando por un saldo pendiente con el banco no se si le informo su mama que', 'la cuenta corriente esta abierta y tiene un saldo que esta deudando de hace mas de', 'yo la estoy llamando de la agencia de cobranza cmo de pc nos comunicamos por el saldo que', 'a mi asegura que ya le habian informado que el saldo actual es de', 'al saldo asi tambien se cubre parte de los pagos minimos con este ajuste pero por', 'del banco bbva si la llamo referencia por el saldo que tiene', 'mire yo lo que le pase es bueno el saldo total es', 'opcion es bueno el saldo total no se se lo informaron es', 'si la llamo referencia por el saldo que tiene pendiente con el banco de la sucursal de', 'si es por el saldo pendiente de agonar', 'de febrero tambien de ese ano pero ha quedado un saldo pendiente que son', 'y despues el viernes puede abonar el saldo restante', 'de cobranza cme opc collection en referencia a lo que corresponde al saldo de la cuenta', 'la deuda usted manana va a ir al banco y va a confirmar con el banco que usted tiene un saldo pendiente que ya le digo cual es', 'si lo estaba llamando en relacion al saldo de su tarjeta de compra de', 'he pactado con usted senor la cancelacion del saldo pendiente de su hijo pudieron abonar', 'despues de esta semana seguramente se modifique el saldo a deudor', 'valeria me pongo en contacto porque el banco nos ha derivado su legajo por un saldo pendiente', 'claro que el saldo que queda pendiente al dia de la fecha es de', 'estamos por un saldo pendiente con el banco con', 'con esto saldo todo', 'si figura pendiente un saldo de', 'si es por el saldo pediente agonar el banco queria ofrecerle un descuento y un plan de pagos para que pagan sera el mismo', 'nunca me vino un resumen de repente me vino ese resumen con ese saldo', 'si me estaba comunicando referente a un saldo pendiente de', 'si yo me comunico referente a un saldo pendiente de', 'le han pasado cuales es el saldo tal cuales son las alternativas', 'nosotros me queremos dar un pequeno descuento a su saldo pendiente', 'el banco le ofrece sobre ...
# ...
# Frases relacionadas con el tema habla: ['alejandra voy a dejarme de hablar del estudio motc por banco san rapido', 'si con el habla', 'si yo en este momento no puedo hablar', 'con jorge velazquez sardo si el habla si jorge como esta', 'no sabia si le tiene que hablar con el sector comercial en que el lapso de tiempo le dan un nuevo producto y en cuanto tiempo', 'a ver y vamos hablando como continua', 'si habla de meo ipc representamos a american express', 'queria hablar con el german dereo villafanez', 'buenas tardes ariel maximiliano merelaz diego adam le habla del estudio mpc me estaba', 'y quiero hablar con mauricio pesarachiava', 'que tal barbara hablamos hace unas horas', 'no habla el papa', 'a este numero con el que estoy hablando', 'si este es el telefono de la hora pero ellos estan trabajando desde la casa asi que no tengo el numero de ella esta hablando con el guardia', 'meupc hablamos la semana pasada con respecto a lo que es la deuda con bbva', 'si betina si quien habla', 'me volvo a comunicarles con usted del estudio curidico del banco santanderrio le habla noel', 'si soy shao quien habla', 'que tal eh martin maria alcarmen le habla del estudio mfpc por banco santander rio', 'la liliana la hablamos del departamento legal del banco bbu de afances', 'si con el habla', 'eh bueno mama quien habla que tal mi nombre es sabrina me estoy contactando', 'tamara le habla a eliana nicola de la gente a mioipc la llamo por american xc', 'de acuerdo yo a ver yo le doy el tiempo hasta la semana que viene para hablar esto', 'y borraca y despues escribi aca mensaje para el senor orlando bonifacio le esta hablando', 'se ve un mensaje reiterado para iris andrea bunkers ha hablado daniela rosame comunicado', 'llamado es para hablar sobre la deuda que tiene activa la realidad de la fecha con', 'si quien habla', 'buenas tardes estoy hablando con paola', 'si de lo que hablamos obviamente la voluntad que el banco va a tomar obviamente yo puedo', 'como le va guadalupe le habla de la agencia m o p c o representante legal de banco bbva', 'si quien le habla', 'si eliano al haber estado hablando de la agencia de cobranzas mipc por el banco bvva como le vas', 'te escucho como que estuvieras muy lejos diego te habla de meu pc', 'si soy la prima la verdad asi hablando haciendo el tramite', 'yo habia hablado que iba a entregar quince mil pesos y no se cuanto me quedaba las', 'si si habla ella', 'si me habla un poquito mas alto por favor', 'no no quien habla', 'si esa habla', 'te habla el lucia y ese me abogado si si si estimas bien estaba corrupiendo algo', 'quien habla', 'si ella habla', 'para gustavo estamos hablando de la tarjeta que termina el', 'si ella habla', 'voy a hablar con mi hijo', 'es mas alla de lo que hablamos', 'perdi el contacto con la senora con la que estaba hablando en su momento', 'queria hablar por favor con el senor gustavo mario campo', 'si ella habla', 'llamando de american express que necesita hablar con el si es posible', 'dejo mensaje para guillermo turzi le habla daniela rosa me comunico de agencia de cobranzas', 'si buenos dias por favor necesitaria hablar con la senora alejandra cuenca', 'si no me estas hablando de un', 'que tal le habla franco godoy de mpc', 'hablame', 'franco matias si se le habla de la agencia de mdt de cerc representante legal de vvvh', 'perfecto podemos hablar ahora sabrina', 'si buenos dias queria hablar con la senora', 'buenas noches queria hablar con ramon arturo rios el habla el doctor adan del', 'si buenas noches queria hablar con elisa betxlesica maseo', 'que tal carlos habla tatiana maratea de la agencia miopeza representante de american', 'queria hablar con la senora rocha prisila', 'le estaba hablando se corto la comunicacion le esta invitando que le digas a su hermano', 'un mensaje para aldo enrique coronel bildosta le hablamos de mi office collection', 'queria hablar con raul enrique espinoza', 'de estar hablando esta noche con mi hijo', 'que tal mucho gusto le habla lucena benitez de  ...
# Frases relacionadas con el tema tarjeta: ['nosotros teniamos una tarjeta del hbc', 'en relacion a su tarjeta de compras si si por el saldo pendiente en su tarjeta', 'este telefono se lo le dan a mi marido que tiene la tarjeta del banco frances', 'ah ok bueno si jacobo los cinco mil anteriores ya estan acreditados en su tarjeta', 'es por la tarjeta de credito', 'el saldo que debe de la fecha de la tarjeta de credito visa es de', 'yo digo que no y ellos pierden porque yo les estaba a posar la tarjeta', 'todo bien queria confirmar con ustedes tamara si pudieron efectuar el pago de la ultima cuota de la tarjeta corporativa', 'porque paso con el tarjeta shopping exactamente igual', 'vos mandame y despues yo voy a tal vez ver conmigo a enviar aqui la tarjeta', 'entonces si usted no va a sacar prestamo tarjetas creditos', 'de la tarjeta de credito', 'hemos recibido en la agencia el saldo de la tarjeta de credito visa y se sumo lo que', 'bien exactamente tarjeta de credito visa ellos informan que tiene un salvo a la fecha', 'le dije los pagos que tenia la tarjeta', 'en este caso lo llamamos por la deuda actual con tarjeta de credito visa y prestamos', 'es el cierre total de la tarjeta avisa de la sucurson neuken', 'pero se lo vuelvo a decir esta debiendo de la tarjeta avisa habia hecho un plan para', 'bueno la deuda pendiente en este caso es por la tarjeta de credito avisa', 'va al rapitado con el numero suyo de tarjeta y la plata', 'de junio por la tarjeta de credito', 'que tal buen dia me comunico por el solo pendiente en su tarjeta corporativa', 'vvva por la tarjeta de credito visa', 'me dieron no me acuerdo en que fecha me dieron una tarjeta de debito que me dijeron me enganaron', 'si lo mismo en la tarjeta de audas', 'si yo contacto en relacion a la tarjeta de hector anibal gando corporativa', 'ese corresponde a una tarjeta de credito de la tarjeta avisa', 'para pagar la tarjeta', 'al dia de hoy esta debiendo de una tarjeta master casi', 'por eso la tarjeta se cancelo y se genero la deuda total a cancelar de', 'bien lo llamaba en relacion al estado de su tarjeta de credito de', 'julio lo vuelvo a llamar en relacion a su tarjeta de compras de american express', 'recibimos el legajo de su tarjeta de credito directa de american express que lamentablemente', 'en relacion al caldo de su tarjeta de credito de seis mil ciento noventa y cinco pesos', 'no la use nunca no use ninguna de las tarjetas', 'corriente y la tarjeta avisa con el banco bbva', 'si usted tiene la quita en la tarjeta cuando termine de usar las', 'esto corresponde a una tarjeta de credito visa', 'si lo estaba llamando en relacion al saldo de su tarjeta de compra de', 'se puede que lo llamo por su tarjeta de me crees', 'cuando le pida el numero de cuenta y es el numero de tarjeta ahi si puede agonar', 'en la tarjeta visa', 'pesos de tarjeta visa mas honorarios que', 'me estoy comunicando por el tema de la tarjeta visa que quedo pendiente de pago', 'la contacto por la deuda que tiene en la tarjeta visa al dia de hoy son', 'dias de muera generado por la tarjeta', 'gabriel estuvimos tratando de contactarlos por la duda que tienen la tarjeta visa', 'estuve mostrando de contactarla por la deuda que tiene con la tarjeta visa', 'me estoy comunicando cesar por el tema de la tarjeta visa que quedo pendiente de pago', 'no mira no hice el pago porque yo tengo una tengo solicitado a la baja que hizo la tarjeta hace mucho tiempo atras', 'que le quedo pendiente con el banco respecto a tarjeta de credito visa si', 'esto es por un prestamo y unas tarjetas que usted tenia con la entidad', 'no habia ingresos porque no entaban tarjeta a lo cual lo corten el servicio y viren a buscar la terminal en vez de arreglarla', 'tiene tarjeta de debito', 'me quedo con ustedes y tengo una deuda con una tarjeta', 'usted tiene alguna tarjeta de debito', 'yo vi de baja todos los cosas la tarjeta que tenia ahi estaba ahi de baja', 'cobrando una deuda que no me pertenes porque solamente habia se habia gus ...
# Frases relacionadas con el tema hablo: ['buenos dias hablo con jacobo el predojanos', 'que tal le hablo de la agencia de cobranza cmypc por una deuda que el mantiene con bdva', 'buenas tardes hablo con daniel monson parte de aqui le estoy llamando del estudio', 'disculpe hablo con el senor eduard eduardo marpariso si les saludo y vengo en', 'que tal buenos dias hablo con rolando ariel medina', 'si que tal buen dia hablo con el esposo de andrea suarez', 'que tal buenos dias hablo con rocio lujan tromboto', 'buenas tardes hablo con el senor ruben rafael josue', 'buenas tardes hablo con maria salcedo', 'si la ultima conversacion que tengo aca que hablo fue con gladis', 'hablo con leonardo ulua', 'le hablo de prejudiciales del banco frances', 'se le puedo mandar al mail a el cual me hablo hoy', 'disculpe hablo con el senor miguel angel weiss', 'buenas tardes hablo con miguel angel vaez', 'hablo la otra vez que era uy no me voy a recordar le damos el nombre ahora me tiro', 'hablo con patricia rodriguez', 'buen dia hablo con jorge deniz', 'buen dia hablo con jorge deniz', 'si que no hablo', 'si hablo con laura', 'buenas tardes hablo con barbara junino que tal barbara me estoy comunicando del', 'por eso yo no hablo en estos dias', 'estudio juridico mopc hablo con ramon arturo rios', 'si buenas tardes hablo con claudia maza', 'o le hablo con julio alberto panfet', 'como es si ya hablo con esta chica', 'buenas tardes hablo con el senor matrimiliano palacios', 'mira me hablo una senorita', 'claro imagino que usted tendra ese numero de gestion y demas con lo que hablo con', 'ahora hablo con julio oscar cusura', 'como estan buenas tardes hablo con gustavo barrio', 'de que le hablo en el banco me dijeron', 'que tal te hablo de la agencia de cobranza de mi opc por banco princes', 'si hablo con valeria', 'de cobranza cmopc cmopc si por el bpva hablo con natalia more ah si si con natalia', 'que figura que es cash collector por lo que veo que hablo anteriormente', 'ahora hablo con mi marido', 'si hablo con patricia rodriguez', 'hablo con el banco y el banco que me va a decir lo mismo que vos', 'disculpe hablo con el senor david osmar rodriguez', 'buenas noches hablo con el senor miguel angel bai', 'hablo con ariel renzo le devuelvo el llamado del estudio juridico del banco santander rio', 'disculpe hablo con la empresa capagli eicos construcciones', 'claro hablo', 'hablo con el senor carlos augusto cantero', 'despues el whatsapp del cual el whatsapp del cual yo te hablo', 'banco santander rio hablo con constantino noel gutierrez lo llamo senor noel por', 'disculpe hablo con el senor gabriel de loache garcilazo', 'buenas tardes hablo con david', 'con otra persona no se quien sera que hablo', 'que tal buenos dias hablo con el senor nahuel faria', 'que tal buenos dias hablo con la ureta agustin', 'no lo hablo de ustedes', 'que tal te hablo de la ciencia de cobranza', 'buenas noches hablo con adriana', 'disculpe hablo con jonathan fabricio oliva', 'buenos dias hablo con lucas torres lo llamo del estudio juridico del banco', 'hablo con su familia', 'disculpe hablo con el senor luis calderon si con el calderon', 'hablo con daniel gallardo', 'buen dia hablo con walter lacroix', 'viernes si la primera cota de nueve el plan si usted me ha dicho que iba a estar el si perdon como no le escuche hablo en el trabajo si para que me podian hacer una adelanta', 'disculpe hablo con chisela fabiola tosa', 'ya te hablo con la senora', 'mira vos te vas a encargar yo hablo todo las', 'ya se hablo de transferencia', 'que bueno porque imaginese hablo con tanta gente al dia que llego un momento no me imagino', 'bueno me comunico de la agencia de cobranzas mapc del banco de bbva hablo con una familia', 'perdon juan ezequiel si hablo con rodoy juan ezequiel si', 'como le dice ahi o sea hablo conmigo y yo le estuve mandando los mensajes por whatsapp', 'si hablo con ella', 'si buenos dias hablo con clacon soliver', 'hablo con instaurarle lucas ezequiel', 'hablo con la sen ...

# %%
filas = []

# Itera sobre cada fila del dataframe
for index, row in compromiso.iterrows():
  # Extrae la lista de frases de la fila
  frases = row['frases']
  
  # Crea un diccionario vacío para almacenar las frases por tema para la fila actual
  frases_por_tema = {}
  
  # Itera sobre cada tema
  for tema in temas:
    # Itera sobre cada frase
    for frase in frases:
      # Comprueba si la frase contiene el tema actual
      if tema in frase:
        # Añade la frase al diccionario si no existe aún una lista para el tema
        if tema not in frases_por_tema:
          frases_por_tema[tema] = []
        # Añade la frase a la lista del diccionario correspondiente al tema
        frases_por_tema[tema].append(frase)
  
  # Añade el diccionario a la lista de diccionarios
  filas.append(frases_por_tema)

# %%
prueba = pd.DataFrame.from_records(filas)

# %%
prueba
# Out:
#                                                   pago  \
# 0      [el pago tiene que estar antes del mediodia si]
# 1    [si senor como verifico que usted ya pago la d...
# 2              [que yo siempre tenia voluntad de pago]
# 3    [ah bueno si quieren enviarlo de vuelta para t...
# 4                                                  NaN
# ..                                                 ...
# 463  [despues bueno veremos de aca a fin de mes y p...
# 464                                                NaN
# 465                                                NaN
# 466                                                NaN
# 467                                                NaN
#
#                                                  deuda  \
# 0    [bien la deuda que presenta el dia de la fecha...
# 1    [si senor como verifico que usted ya pago la d...
# 2    [que se enteraron de que tenia la deuda que te...
# 3                                                  NaN
# 4    [si necesitaria saber que me confirme hoy si v...
# ..                                                 ...
# 463  [pedro lo contacto por su deuda con el banco s...
# 464                                                NaN
# 465                                                NaN
# 466                                                NaN
# 467                                                NaN
#
#                                                  pesos  \
# 0                                              [pesos]
# 1    [pesos si tengo que hacerle nuevamente un plan...
# 2                                       [pesos, pesos]
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 463  [pesos, pesos cada uno lo ayudan a poder cance...
# 464                                                NaN
# 465                                                NaN
# 466                                                NaN
# 467                                                NaN
#
#                                               whatsapp  \
# 0    [yo le voy a enviar tiene whatsapp en este num...
# 1                                                  NaN
# 2          [nosotros tenemos el contacto por whatsapp]
# 3    [igual tengo tu whatsapp asi que yo apenas dep...
# 4                                                  NaN
# ..                                                 ...
# 463                                                NaN
# 464                                                NaN
# 465                                                NaN
# 466                                                NaN
# 467                                                NaN
#
#                                                  pagar  \
# 0    [perfecto pero lo puedo pagar el martes que vi...
# 1                                                  NaN
# 2    [si si era la unica tarjeta no por falta de pa...
# 3                                                  NaN
# 4    [si necesitaria saber que me confirme hoy si v...
# ..                                                 ...
# 463  [tendria que pagar una cuota y el otro, que vi...
# 464                                                NaN
# 465                                                NaN
# 466                                                NaN
# 467                                                NaN
#
#                                                 cuenta  \
# 0    [ahorita la voy a agregar al whatsapp y le voy...
# 1    [bueno senor para que tengan cuenta entonces e...
# 2    [toman la decision de dar de baja la cuenta po...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 463                                                NaN
# 464                                                NaN
# 465                                                NaN
# 466                                                NaN
# 467                                                NaN
#
#                                                 llamar  \
# 0                                                  NaN
# 1           [y bueno me tenes que llamar a fin de mes]
# 2                   [volvimos a llamar porque sabemos]
# 3                                                  NaN
# 4    [quiere llamarme mas tardecito yo me comunico ...
# ..                                                 ...
# 463                                                NaN
# 464                                                NaN
# 465                                                NaN
# 466                                                NaN
# 467                                                NaN
#
#                                            cuotas  \
# 0                                             NaN
# 1                                             NaN
# 2    [las cuotas, esta bonificacion y las cuotas]
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 463                                           NaN
# 464                                           NaN
# 465                                           NaN
# 466                                           NaN
# 467                                           NaN
#
#                                                    hoy  \
# 0                                                  NaN
# 1                                                  NaN
# 2    [hoy desde poder informar, ahi esta mi situaci...
# 3    [en estos dias tiene que ser lo te digo porque...
# 4    [si necesitaria saber que me confirme hoy si v...
# ..                                                 ...
# 463  [pesos hoy en dia no es nada es una salida con...
# 464                                                NaN
# 465                                                NaN
# 466                                                NaN
# 467                                                NaN
#
#                       telefono  \
# 0                          NaN
# 1                          NaN
# 2    [el telefono por ejemplo]
# 3                          NaN
# 4                          NaN
# ..                         ...
# 463                        NaN
# 464                        NaN
# 465                        NaN
# 466                        NaN
# 467                        NaN
#
#                                                momento  \
# 0                                                  NaN
# 1                                                  NaN
# 2    [esta sin trabajar usted esta sin trabajar en ...
# 3                                                  NaN
# 4              [si yo en este momento no puedo hablar]
# ..                                                 ...
# 463                                                NaN
# 464                                                NaN
# 465                                                NaN
# 466                                                NaN
# 467                                                NaN
#
#                                                 nombre  \
# 0                                                  NaN
# 1                                                  NaN
# 2              [la tarjeta de la hbc estaba su nombre]
# 3    [porque vio que estamos cobrando con ese que a...
# 4                                                  NaN
# ..                                                 ...
# 463                                                NaN
# 464                                                NaN
# 465                                                NaN
# 466                                                NaN
# 467                                                NaN
#
#                                                  habla  \
# 0                                                  NaN
# 1                                                  NaN
# 2    [alejandra voy a dejarme de hablar del estudio...
# 3                                    [si con el habla]
# 4              [si yo en este momento no puedo hablar]
# ..                                                 ...
# 463  [queria hablar con usted para saber si va a re...
# 464                                                NaN
# 465                                                NaN
# 466                                                NaN
# 467                                                NaN
#
#                                                tarjeta saldo hablo
# 0                                                  NaN   NaN   NaN
# 1                                                  NaN   NaN   NaN
# 2    [nosotros teniamos una tarjeta del hbc, que me...   NaN   NaN
# 3                                                  NaN   NaN   NaN
# 4                                                  NaN   NaN   NaN
# ..                                                 ...   ...   ...
# 463                                                NaN   NaN   NaN
# 464                                                NaN   NaN   NaN
# 465                                                NaN   NaN   NaN
# 466                                                NaN   NaN   NaN
# 467                                                NaN   NaN   NaN
#
# [468 rows x 16 columns]

# %%
compromiso.transcripcion_limpia[0]
# Out:
# 'si maria me escucha este corton     si le escucho le escucho     bien la deuda que presenta el dia de la fecha son   pesos     y solo que le puedo ofrecer para que cancele con el descuento de este mes de abril     que vence el martes que viene es un descuento mas     no manana     no manana el otro el otro martes     es un descuento que le puedo dar del     casi  con  cancelan la deuda     perfecto pero lo puedo pagar el martes que viene     si usted le mando un link o algun codigo o algo para que yo pueda pagar     yo le voy a enviar tiene whatsapp en este numero     si     bueno yo le voy a enviar un whatsapp     el pago tiene que estar antes del mediodia si     a mas tardar a las  horas porque en ese horario hay que entregar los tickets al banco si     ahorita la voy a agregar al whatsapp y le voy a pasar el numero de cuenta donde tiene que pagar     es una cuenta corriente o un cbu     puede ir a cualquier santander con la cuenta corriente     o si no hace una transferencia con el cbu     cualquiera de las dos formas luego necesito el ticket     estoy trabajando y mire yo soy directora de una escuela     estamos bastante complicados con este tema del covid     y bueno estamos trabajando con personal reducido     por eso si yo le puedo hacer una transferencia va a ser mejor     si no hay problema     ahi en el numero que le voy a pasar tiene el cbu hace la transferencia     cuando paga le saco una foto al ticket y me lo envia por whatsapp     y cargo la cancelacion     por el mismo whatsapp     el mismo whatsapp que yo le voy a escribir en unos minutos     esta apenas termina de cargar el acuerdo en el banco     perfecto     listo maria ahora agendo al whatsapp y le paso los datos     bueno le agradezco mucho     no de nada que tenga buen dia     muchas gracias'

# %%
prueba.pago[1]
# Out:
# ['si senor como verifico que usted ya pago la deuda entonces estaria quedando con el',
#  'entonces ahora ya verifico que dos meses no se pago entonces tuvo otra vez un incremento y todo esto']

# %%
prueba.pago.astype(str).unique()
# Out:
# array(["['el pago tiene que estar antes del mediodia si']",
#        "['si senor como verifico que usted ya pago la deuda entonces estaria quedando con el', 'entonces ahora ya verifico que dos meses no se pago entonces tuvo otra vez un incremento y todo esto']",
#        "['que yo siempre tenia voluntad de pago']",
#        "['ah bueno si quieren enviarlo de vuelta para tenerlo mas fresco pero apenas me depositen voy y les pago']",
#        'nan', "['lo recuerdo y siempre pago un poquito de esto despues']",
#        "['eso te queria decir porque ella pago', 'o sino que le vuelvo a escribir a rosa que es la persona que le hizo el acuerdo de pago', 'se cargo el pago']",
#        "['para cuando podriamos agendar otra vez su pago', 'bueno esta bien le regiendo su pago entonces senor']",
#        "['mientras yo espero el pago la acreditacion del pago de ayer si']",
#        "['y si usted esta autorizada para cerrar un acuerdo de pago', 'le envie propuestas de pago', 'con un salpago y en cuota', 'si lo ponen en un salpago', 'lo ponen en un salpago', 'una cosa y con el tema por ejemplo donde pago']",
#        "['o no se o cupones para pagar en un rojo y pago o la cuenta para hacer la transferencia', 'estoy haciendo la transferencia o el pago']",
#        "['la primera es obviamente por pago al contado', 'en un pago en el mes de mayo despues hablamos que pudiera las fechas de versimiento este pago', 'cancelar con un pago de', 'pesos al contado si la segunda opcion es en dos pagos de', 'y la tercera opcion en tres pagos', 'ya le digo de cuanto en tres pagos de', 'o sea en tres pagos', 'en dos pagos', 'residuos de sueldo y de cuales son los medios bueno pago y quiere o esto si es mas', 'que sea cual sea la situacion esto habria que cerrarlo ahora y se tendria que estar pago', 'ningun pago parcial porque otra cosa supongamos que pudiera que el sueldo del ingreso se']",
#        "['no me dieron los datos del estudio para que abone por un pago facil', 'pero con ese primer pago ya estaria la primer cuota y las otras o siguientes las abonas', 'abono por rapid pago pago facil suele demorar', 'el comprobante asi yo lo remito y bueno ya se queda tranquilo y el proximo pago seria', 'los datos que solo le paso puede abonar tambien por rapid pago pero puede abonar tambien', 'el pago', 'yo me complica demasiado prefiero hacerlo por pago facil', 'y bueno a partir del mes que viene ya el pago lo abona y nos manda el comprobante a nosotros']",
#        "['por el pago del banco frances del dia de hoy', 'puedo pagar el pago del banco frances del dia de hoy']",
#        "['o mercado pago tambien puede ir directamente al banco santander rio nosotros le mandamos']",
#        "['realizado el plan de pago']",
#        "['el primer pago tiene que estar a mas tardar del dia viernes']",
#        "['si el pago usted lo usted lo prefiere irse al banco a bonar o lo hace por transferencia', 'vez que haga el pago nos envie la foto de su comprobante para que podamos cargar al', 'si el se una vez que nosotros cargamos el pago estara a', 'y que dia usted realiza el pago de eduardo entonces para notar y no molestarle de nuevo', 'si en el transcurso de esta semana yo hago el pago']",
#        "['pudo realizar el pago que se habia comprometido a abonar']",
#        "['lo llamo porque le habia enviado el mail con la propuesta de pago no se si lo pudo chequear']",
#        "['y a quien cuenta con la posibilidad de poder ir en contra de la duda y revisando a pago', 'puedo hacer algun plan de pago o no']",
#        "['visto la que la cancelo he echado y no le pago mas', 'ya esta ya que ellos hagan la deuda que quieran yo no le pago mas nada']",
#        "['sea enviado a legales y se inician las acciones correspondientes por incumplimiento de pago', 'correspondientes por incumplimiento de pago tiene muchos dias de atraso la deuda de']",
#        "['todo bien queria confirmar con ustedes tamara si pudieron efectuar el pago de la ultima cuota de la tarjeta corporativa', 'si lo van a estar realizando manana el pago']",
#        "['lo que le voy a pedir es que el primer pago sea lo antes posible para hacerlo en cuotas', 'no la verdad que yo para pagarte si yo te ya este no es no no tengo como para decir que ya te pago']",
#        "['como hacer el pago por transferencia', 'si pero bueno yo la vi leyenda pero por las dudas para que se entienda como hacer el pago', 'vos ustedes eligieron la opcion transferencia de pago', 'si transferencia pago', 'y yo digo bueno pues eso es lo que pago dos cuotas juntas se puede pagar dos cuotas juntas', 'los pagos son mensuales y consecutivos cada', 'porque el banco nos va a dar de baja al convenio por no haber pagos cada', 'hay que hacer los pagos cada', 'hubiesemos hecho el plan de un pago era un pago de', 'el pago de']",
#        "['preferente el compromiso de pago que dejamos asentado con un companero quisiera saber si ya abono la primera cuota']",
#        "['el banco no se si le informaron el saldo total las posibilidades de pago', 'tuvio una residenciacion que no cumplio el pago y por eso paso al cobro', 'o le haga un cupon de pago y paga por ventanilla', 'el mismo pago lo tiene que hacer el mismo mes que viene', 'el cliente gestiona un plan de pago paga cancele y el banco le tramita el libre deuda', 'dias del ultimo pago', 'o eso tiene la posibilidad de cancelarlo en un pago o dos', 'si usted confirma el pago', 'con el efectivo de realizar el pago', 'estas son las bocas de pago', 'un pago de', 'hasta en seis pagos de', 'asi le paso el cupon de pago para que pague']",
#        "['si nada mas para recordarle el compromiso de pago para el dia de hoy']",
#        "['en un pago el banco se lo deja en', 'o tres pagos de', 'en efectivo con el cupon de pago que le doy']",
#        "['pagos a cuenta cargamos un pago a cuenta de', 'cancelar en uno o dos o tres pagos ahora del', 'pagos esas quitas estan siempre vigentes lo que urge si es que este mes empiece a pagar', 'pagos a cuenta de', 'pagos de']",
#        "['porque no hemos recibido a auto comprobante de pago y la cuota esta vencida cuando se esta reclamando los']",
#        "['de los de la manera de pago en nuestras clientes nosotros tenemos la opcion de facilitar', 'y bueno y la cuenta donde estas que pago ok senor sin problemas le facilitamos']",
#        "['es lo que usted sabe si hay plan de pago', 'si obviamente hay plan de pago', 'realizar el primer pago', 'de pago', 'un recordatorio de pago', 'la idea del recordatorio de pago', 'recordatorio de pago', 'mantener el plan de pago', 'ver el plan de pago', 'realice el pago', 'informando el pago', 'siempre tiene que hacer usted el que informa el pago', 'que me informa el pago']",
#        "['cuando nos desciaban estan ahi en el cajero en el pago ufar si no en el rato no no']",
#        "['lo pago antes asi ya estar un cosa terminado']",
#        "['opcion ya tendriamos que ir por un plan de pago comenteme su situacion a la fecha', 'y se puede cancelar con la bonificacion en un pago', 'poder emitir los libres de deuda a los treinta dias de realizado el pago cancelatorio usted', 'si no lo puede hacer usted es el pago hacerlo mediante transferencia bancaria o sea puede', 'el pago lo puede hacer por transferencia bancaria desde cualquier cuenta no necesariamente tiene', 'y como hago para hacer la transferencia no le paso ahora por whatsapp usted el pago', 'no el pago lo puedo hacer ya pero bien']",
#        "['yo voluntad de pago tengo', 'no evidentemente voluntad de pago no tiene porque yo le explique todos los gastos que tenia el resumen', 'igual yo recuerdo perfectamente el dia que cerramos el acuerdo de pago cuando yo le explique todos los gastos que tenia', 'el dia que yo cerre el acuerdo de pago con ustedes el dia', 'mandame el resumen y te aseguro que te lo pago inmediatamente una vez que lo compruebes', 'porque esto esta pago', 'es que ahora me voy a pagar entonces si te apuro te pago', 'porque lo que me esta reclamando esta en pago', 'y te voy a demostrar que esta pago', 'le dije los pagos que tenia la tarjeta', 'y usted me dijo bueno lo pago', 'pero lo pago en dos cuotas porque ahora no puedo cancelar todo', 'pero este acuerdo de pago se le va a caer', 'yo estoy en condiciones de pago', 'que tengo pago', 'que estan impagos', 'y lo pago', 'yo no pago nada porque', 'cual es el medio de pago']",
#        "['pero bueno para aclararle usted lo que tiene que hacer es el pago del anticipo de', 'o sea que pago primero', 'es lo siguiente yo pago siempre cuando pueda y las cosas me las acomoden tambien alguna forma', 'te pago', 'y eso yo pago eso hoy y dentro de']",
#        "['he recibido en el dia de hoy el mail si con el pago', 'hasta el mes que viene si yo pago todo de uno', 'se cancelan un solo pago', 'hay voluntad de pago por parte del cliente', 'no tenemos ningun problema en que se abone en un solo pago']",
#        "['si yo me estaba comunicando para recordarle de su pago senor miel', 'para tomarles nuevamente los datos del pago miguel si', 'sin problemas con su dni se acerca a su mujer y le van a tomar el pago senor']",
#        "['en este caso nosotros lo que hacemos es una refinanciacion o ver a un convenio de pagos', 'la manchopate de la deuda ademas es que como yo hice fui a hacer el pago al banco', 'ultimo no pago que es lo que tengo que pasar', 'a ver el ultimo no pago de bbv tenemos en abril un debito de', 'que pago puede realizar antes de que se cierre el mes usted', 'cancelaciones se hacen en un solo pago si', 'bueno lo podemos hacer pero de esta manera le va a quedar en un solo pago de', 'a donde tengo que hacer el pago yo ahora le voy a dejar usted primero para confirmar', 'horas pago por transferencia o', 'mercado pago como usted quiera si bien no hay problema bien nosotros le dejamos']",
#        "['el compromiso de pago con el banco santander', 'entonces en el transcurso del dia de hoy o de manana fecha veintidos aguardamos el pago', 'entonces seria el veintidos de cada mes el pago de diez mil doscientos si']",
#        "['queriamos bueno en realidad saber bien de cuanto era la deuda que tiene y al ver alguna forma de pago', 'bien alguna forma del pago de esto tiene que ser recontada', 'hasta en tres pagos se puede hacer sin quita si', 'en un pago tiene la oposidad de hacerlo como una quita si', 'en un pago se puede cancelar con', 'en un pago', 'en tres pagos', 'en tres pagos', 'en tres pagos le quedarian tres pagos de', 'si en un pago o en dos o en tres perdon que es sin quita']",
#        "['pero a partir del mes de julio abonaria ese dinero el primero es el pago de la anticipacion']",
#        "['eh nos estamos comunicando porque bueno tanto tenemos todavia el pago que habiamos acordado']",
#        "['puedo realizar tu pago al dia de hoy jorge', 'puedo acercarte al banco santander rio o lo puedo hacer directamente por mercado pago', 'no y acercarte al mercado pago y como lo hago']",
#        "['entonces le pido por favor que me haga llegar el comprobante de pago', 'entonces acuerdense de enviarme la foto el pago perdon', 'pero si manana os sigue el pago este porque es la unica opcion']",
#        "['y vamos a ver cual es el ultimo pago informado', 'el ultimo pago fue en noviembre del ano pasado', 'la forma de pago en este caso', 'en un solo pago descontando todos los intereses a la fecha', 'le quedaria en un solo pago en vez de', 'le quedaria en un pago de', 'la cancelacion es en un solo pago', 'y lo puede cancelar en dos pagos de', 'me quedaria en dos pago', 'solamente en dos pagos', 'el pago se hace por el autoservicio banco frances', 'horas pago por transferencia o mercado pago', 'con el numero de tarjeta o como se viene el auto pago', 'esa es la forma de pago que tiene', 'si tiene que analizar si lo puedo hacer en dos pagos', 'pagos', 'hasta que no se registre un convenio de pago', 'una vez que nosotros informamos al banco la forma de pago que va a tener']",
#        "['y el pago se impacta directamente si', 'o te lo pago en dos veces', 'bueno entonces va el rapitpago tienes que ir al rapitpago', 'posibilidades de pago', 'tiene un monton de posibilidades de pago pero no las vas a ver manejar porque las posibilidades de pago que tiene son bueno', 'tiene un monton de posibilidades de pago en la ventanilla del banco que le van a dar turno a', 'pedis a mi pago porque es el mas facil porque va con el numero de la tarjeta y la plata y se lo pago']",
#        "['buenos dias jose me contas esto por el pago pendiente que tiene con fecha', 'ah entonces no no se falta o sea si lo pago lo tiene sentido', 'pero para yo si yo lo pago yo tengo que transmitirle el libre deuda al veraz']",
#        "['pesos en un pago']",
#        "['ese pago te van a estar permitiendo refinanciar por ejemplo ya te informo cual seria el', 'y demas sino con la agencia que serian los pagos siempre en la cuenta de la agencia', 'pesos si que son los que son disponibles en un pago o si', 'no estan dos pagos porque vos si obviamente tomas una opcion todo lo que vos haces fuera', 'cuotas con nosotros se registra en sistema para que nosotros cuando recibamos tu pago', 'en la cuenta de la agencia todos los meses que se derive el pago figure como cumplir', 'pagos de']",
#        "['para que pueda cancelar en un solo pago con menos dinero']",
#        "['o a traves de mercado pago', 'sin enviarle la propuesta de pago', 'sentada la propuesta de pago', 'me reenviase con probante de pago', 'por su grupo de pago']",
#        "['algun plan de pago para regularizar su situacion con el banco es solo saber que esta malo', 'acuerdo de pago porque habia hecho un acuerdo de pago y luego este signo de baja solamente']",
#        "['si no lamentablemente la tengo que pasar como negativa de pago si no tengo el pago para esa fecha lamentablemente lo tengo que pasar directamente como negativa de pago al banco']",
#        "['banco queria ofrecerle un descuento y un plan de pagos para que pueda cancelar el mismo']",
#        "['no sea problema yo ya lo dejo registrado que esta hecho el pago directamente']",
#        "['tengo que pasar los datos del pago los datos de la cuenta si no lo voy a poder pagar', 'si voy al banco frances y esto lo pago en el banco frances el banco frances me tiene', 'la palabra de que aceptar el pago porque es mi acredito', 'yo si no es un pago']",
#        "['lo que se hace es tratar de ver un plan de pago o la forma de que lo pueda cancelar', 'en el caso de que cancelen un pago y luego lo unico que se hace es informar la cancelacion total', 'el banco envia la opcion de cancelar en un pago o en dos votas con un descuento de', 'en el pais jamas yo deje de hacer un pago en nada', 'el caso del saldo con descuento se puede hacer hasta en dos pagos', 'la fecha de pago de esa opcion', 'yo le paso los datos para que pueda hacer el pago', 'porque obviamente le vamos a pedir el pago en una cuenta que no es propia', 'la primera opcion que es sin descuento lo puede hacer hace en cuatro pagos fijos', 'la segunda opcion que es con descuento solamente dos pagos', 'y sea dos pagos ahora y el otro con dos dias', 'dias del primer pago', 'para el primer pago', 'de julio tendria que ser el segundo pago']",
#        "['bien realizar un plan de pago totalmente en cuota fija sin intereses', 'tiene la posibilidad de cancelarlo de cancelarlo asi en un pago', 'y si yo lo ofrezco cancelarlo y lo hacen dos pagos', 'tiene trata tiempo al viernes a ver si alguien le puede facilitar el dinero como para poder para poder realizar el pago']",
#        "['bueno yo ya le avise luego que va a matar el papel de pago todo']",
#        "['un plan de pago o algo asi usted', 'pesos se le habia ofrecido una cancelacion en un pago con descuento que', 'pesos o un pago minimo que era', 'el acuerdo de pago estan las propuestas pero nunca se llamo para confirmar que iban', 'a abonar no hay fecha de pago nada', 'bueno se las mando por whatsapp a las opciones le pido que me conteste y la fecha de pago']",
#        "['ahora lo que tenemos que hacer es generar un acuerdo de pago o la cancelacion de la deuda', 'si me vas a pagarlo todo junto o sea tenemos que hacer un acuerdo de pago sobre', 'hay dos opciones una puede ir a cualquier sucursal de bbva con un numero de cuenta que yo tengo que informarle para que realice el pago', 'horas posterior al pago la va a identificar a traves de la pagina de francesnet para firmarla online', 'el mes que viene cuando sea la primer cuota de la refinanciacion el banco le va a dar un numero de caja de ahorro para que usted realice los pagos a traves de ese numero de caja de ahorro', 'si es el acuerdo de pago como el acuerdo es interno o sea que queda en el estudio en su caso con la quita que le estamos ofreciendo los tres pagos los va a realizar o a traves de la cuenta que le vamos a informar de bbva o por transferencia bancaria que puede ser mercado pago', 'en el caso que usted acepte hacer la cancelacion en tres cuotas pude sosperarla para que realice el primer pago hasta el dia', 'este pago tiene que estar realizado a mas tardar el dia lunes porque hay un proceso que es la carpeta', 'de aparte el pago de la tarjeta por ejemplo hay un pago el dia', 'despues del pago', 'exactamente no son fijas siempre va a ser a favor del cliente porque al ser el sistema frances va a ir habiendo todos los meses una variante en el pago', 'no hay ningun problema de esperarla para que realice el pago del anticipo y en el mes de julio estaria abonando a hacer la primera cota de quince']",
#        "['me estoy comunicando por el tema de la tarjita visa que quedo pendiente de pago', 'inicialmente para poder acceder al acuerdo tiene que hacer un pago de']",
#        "['si si yo vengo con un retraso del pago de esa tarjeta estoy con inconvenientes laborales', 'y se me complica mucho poder concretar un pago un pago que podamos acordar para entrar', 'a los que me estan prometiendo de pago no', 'claro y es decir todavia por lo que me comentan no puede digamos pasar un acuerdo de pago', 'bien carlos y la posibilidad por lo menos de ir haciendo pagos parciales como hizo', 'si es obvio la voluntad de pago la tengo es decir el tema es que entiendo que la cuota', 'no puedo comprometernos si vos me decis con un compromiso de pago yo no hago el esfuerzo', 'al saldo asi tambien se cubre parte de los pagos minimos con este ajuste pero por', 'eso le digo mas que nada por lo menos haga un pago parcial de lo que pueda abonar mas', 'que nada tambien para ir demostrando la voluntad de pago american express como el', 'ultimo pago fue el', 'en un ancor de pagos ir cubriendo estos pagos minimos pero por lo menos usted avance', 'aunque sea un pago parcial lo maximo que pueda bonar digamos y yo pido este ajuste', 'que viene ellos van haciendo pagos parciales y de ahi veo depositar algo', 'si pudo realizar el pago si']",
#        "['en un pago cancelamos con']",
#        "['nosotros le pasamos unas propuestas de pago']",
#        "['o en forma de transferencia por mercado pago o home banking', 'despues de que pago la ultima cubota']",
#        "['usted pudo verificar el pago', 'pasame este por favor el acuerdo de pago la carta que diga del acuerdo de pago y la cvsu y se lo hacemos en el acto', 'si vos me preparas un acuerdo de pago de lo que ya lo cancelamos despues me decis de donde se refira libre deuda y lo que sea', 'dias habiles despues de que haya realizado el ultimo pago que seria el pago cancelatorio', 'bien pero uo me puede dar el restimo de pago', 'la cancelacion de deuda va a ser con el pago de la transferencia', 'pero pasame algo antes que diga yo tengo que transferir a este numero de cuenta para el pago o cancelacion del total de las deudas ok', 'en la compuesta de pago']",
#        "['dependiente de pago que corresponde a un saldo de', 'no puedo generar ese pago yo me estare comunicando el momento de que', 'ese pago bueno cuando se cree que ya que lo puede estar acumulando', 'porque si tiene intencion lo que se le puede armar es un plan de pago para que usted lo', 'un rato mas o menos tipo una hora y media y vemos el plan de pago que me aprecia']",
#        "['de pago', 'de iniciar los pagos ahora este mes de junio', 'pago de', 'o quizas le interesa mas lo que es la cancelacion en un pago', 'si generalmente los planes que son con un pago obviamente son en cuanto a interes']",
#        "['la fecha de pago que puedo darle con este plan', 'mas cuotas necesitan que se inician los pagos pronto', 'fecha maxima de pago seria el', 'ya este realizando el pago']",
#        "['creo que es la propuesta le quedaria un pago de', 'tengo mas descuento la segunda opcion es en tres pagos de', 'siempre siempre le van a convenir los planes en un pago porque son lo que mas descuento tienen']",
#        "['querias saber si tenia alguna novedad referente al pago', 'tendria que haber bueno tenia alguien o sea directamente ya tengo que avisar al banco la negativa del pago porque no podemos esperar nada mas', 'tiene que estar el pago a mas tarde del lunes al mediodia']",
#        "['bueno y queriamos hablarse para el dia de manana podiamos contar con su pago', 'si me dan una forma de pago o algo minimo bueno pero el total imposible por lo menos', 'es un plan de pago si', 'realizar el pago si']",
#        "['y necesito el pago que esta vencido', 'para que vuelva a hacer el pago sabes', 'hoy o manana me voy a decir hacer el pago', 'depende de que cumples con el pago']",
#        "['el banco queria ofrecerle un descuento y un plan de pago para que va a cancelar el mismo']",
#        "['de diciembre del ano pasado pago', 'en este mes ahi un pago senorita', 'cuando pago', 'eso se pago el dia', 'un correo con un plan de pagos', 'si pero se lo mande en abril esto y nunca pago', 'usted me mando un correo con un plan de pagos', 'pago hagamos los siguientes el lunes tratemos de buscar un nuevo plan de pagos', 'arregle un plan de pago', 'pero julio ya le di el plan de pago', 'tiene que hacer es acordar un plan de pago', 'entonces necesito acordar el plan de pago']",
#        "['de marzo de este ano revise y el ultimo pago registrado es de', 'esos saldos porque hubo un reclamo ahi sobre unos pagos que no correspondian es decir', 'asi que entiendo que corresponde el pago lo que si quieres usted recibio', 'cualquier duda que tengan quedo a su disposicion asi ya pautamos el pago y todo se puede resolver', 'si si si porque no no no es el tema de no pagar la duece pues solo el pago lo']",
#        "['menos en el dia de hoy puede hacer un pago de quinientos pesos', 'si si si si bueno este pago vagalo por lo menos en el dia de hoy asi cubre', 'el pago minimo mas atrasado y evita sumar intereses en la cuenta si', 'como para no ir al rapid pago y tener que si si puede abonar por pago mis cuentas', 'usted nunca abono con la tarjeta por pago mis cuentas', 'en ese mercado pago mio mercado pago que es donde yo transactivo mando pero nunca', 'he pagado desde ahi a america claro no mercado pago no le toma el pago', 'si pago mis cuentas y usted tiene pago mis cuentas habilitadas con alguna cuen', 'claro en este caso le tomaban pero bueno si no si en rapid pago a mas tardar entre', 'hoy o manana haga el pago de quinientos pesos', 'asi que no me queda otra que es rapid pago porque despues tengo para transferirse directamente', 'tiene pago mis cuentas o con banking puede transferir siempre a los quince igitos de', 'por ejemplo usted paga pone pago y le aparece pago de tarjeta', 'un pago', 'usted entre hoy o manana hace un pago de', 'o cuando se pago me yozo']",
#        "['lo estabamos llamando a ver si podemos cerrar un acuerdo del pago tenemos un descuento']",
#        "['con los datos de pago cuanto es el total', 'y se podra por mercado pago o pago mis cuentas', 'a traves de transferencia por mercado pago si']",
#        "['mil pesos pero tiene que pagar en un pago', 'como no pago por tres meses lo derivaron aca', 'no me voy a decir entonces como lo pago y']",
#        "['que esto lo pueda bonar en un solo pago cancelatorio', 'vamos a un plan de pagos de tres cuotas si en todo caso si llega una modificacion', 'usted me avisa porque hay que anunar este plan y hacerlo en un solo pago si', 'con la intencion de pago pueda abonarlo si', 'de pago de la primer cuota lo que es el lunes', 'si si lloro ahora primero confirmamos bien la fecha de pago y ahora le comento', 'y finaliza el tan de pago el lunes', 'plan de pagos o cancela asi que asi quedamos tranquilos asi no estar', 'con el plan de pagos que tiene tres cubotas o una cancelacion']",
#        "['pero vos sabes que yo estoy sin trabajo vos sabes yo no se con quien hablar o para quien me hagan un plan de pago', 'claro sergio hay la posibilidad de que podamos llegar a algun acuerdo de pagos', 'claro y si vos me haces un plan de pago por mes asi', 'usted en el dia de hoy puede avanzar con el pago de la primera cuota', 'bien si no ya empezamos a organizar el pago', 'mas que nada para que le llegue el acuerdo de pagos con los vencimientos', 'usted entre hoy o manana haga un pago parcial por lo menos un adelanto de la cuota', 'bueno haga ese pago de', 'perfecto sergio el pago lo hace como asi habitualmente a los', 'lo puede abonar por rapid pago si no pago mis cuentas transferencia bancario por los bancos habilitados', 'entonces yo manana me comunico para registrar el pago de los', 'y ahi ya despues les va a llegar el acuerdo de pago si', 'cuanto es el pago', 'si es el pago para que no se suben intereses en la cuenta', 'bien con el pago de la tercera cuota empieza a ser informado positivamente en el banco central si', 'sergio yo manana me vuelvo a contactar asi dejamos registrado el pago']",
#        "['bien y si no hay alguna consulta por transferencia o por pago mis cuentas que puedas llegar a bonar', 'ah voy a intentar desde mercado pago bueno ahora intento desde mercado pago', 'desde mercado pago no toma el pago si tiene habilitado pago mis cuentas en home banking']",
#        "['si si si si me ha trazado un pago', 'ok entonces dejamos un pago para manana']",
#        "['tiene la opcion de poder pagarlo por transferencia con banquin mercado pago o por deposito', 'en un rapipago en cualquier sucursal del banco santander rio o en los cajeros del', 'pago facil no se puede']",
#        "['yo le pago si vos no me detallas', 'yo no confio entonces no pago', 'cuando mas o menos realiza el pago']",
#        "['tres pagos', 'papeles para pagarlo entre pipago o pago facil', 'ya lo tengo asi lo pago antes del']",
#        "['rio para confirmar si pudo realizar el pago ya les mando el aferto del cunton ah perfecto']",
#        "['realizar el pago con seguridad perfecto', 'en la cumba propago tiene que ser cincuenta en el banco', 'perfecto bien aguardamos el pago senora susana']",
#        "['lucas yo pido una prorroga de pagos hasta el dia viernes', 'asi nosotros podemos registrar el pago', 'te contestamos que hayamos ingresado o sea que verificamos el pago en la cuenta', 'ah despues de que yo hago el pago', 'despues que haces el pago treinta dias porque esto va con el cierre de visa']",
#        "['yo eso lo pago en la sucursal que acabe en mi localidad']",
#        "['las opciones de pago para que pueda regularizar perfecto bien aguardo un momento que ya le', 'saltar en un pago le puedo ofrecer un plan en cuotas no me gustaria hacerlo solamente en un pago', 'la tarjeta ya esta inhabilitada si por falta de pago la misma no se va a poder volver a', 'bien como puedo realizar el pago el pago se hace por autoservicio del bpva a la', 'si y recuerdo una vez que haga el pago enviarme la foto del comprobante si envieme una captura', 'para que yo pueda acreditar el pago a su dni lo confirmo entonces la cancelacion en un pago de', 'traves del whatsapp y le aguardo el pago manana entonces perfecto perfecto muchas gracias']",
#        "['me estoy comunicando por el tema de la tarjeta visa que quedo pendiente de pago', 'si porque despues cuando por unos dias yo me demore que no me pago', 'si no es como que mejor no lo pago y ya esta lo dejo ahi', 'y los pocos que hizo si se acreditaron yo por eso veo el pago que hizo en febrero y en marzo', 'yo voy y los pago', 'me interesa pagar porque siempre fue buena pagadora y siempre tuve el dia en mis pagos', 'por eso era que era menor el saldo que iba a cancelar y los pagos', 'vere si hay alguna tarjeta que me quiere dar alguna forma de pago', 'directamente dije no la pago mas y que sigan subiendo lo que tengan que subir', 'bueno yo le puedo ofrecer otra alternativa de pago', 'pero yo por eso le digo se puede hacer otra forma de pago', 'lo que yo tengo es un pago de', 'un pago de', 'como mucho en dos pagos', 'pero igualmente el pago lo va a tener que hacer para el banco buba', 'me puede mandar este whatsapp con las fechas de pago']",
#        "['lo que es el pago si', 'porque yo habia hecho los dos pagos pero nunca me mandaron el libre de deuda', 'se abonaron a ver me figuran a julio agosto octubre que se abonaron todos estos pagos ya estan descontados', 'igual ahora por las dudas para corroborarlo envieme los comprobantes si por las dudas de que no haya algun pagos eso lo corroboramos claramente', 'hagamos eso yo ahora se lo envio lo que es el libre de buda que consulto eso se emite automaticamente una vez que el ultimo pago en este caso este acreditado', 'si hagamos eso yo ahora le abro el por whatsapp sandra envieme eso si ya dejamos asentado en todo caso el pago al', 'no hay ni igual si lo tenes hecho ni por de lo que se esta hecho hago esto se hace el pago y listo', 'en el caso de que haya dado antes el pago simplemente exacto me envie el comprobante']",
#        "['directamente pasa como que esta negativa de pago me entiendes en rebeldia', 'pesos si haciendo un pago de', 'claro si de hecho esto puede cancelar con un descuento muy importante en el caso de abonar en un pago', 'si si esto cancela si puedes pagarte el pago o sea el pago el descuento al titular', 'el pago no es personal', 'en ese caso si el cancela si en un pago o sea le digo como puede', 'yo le informo a los datos de ese pago a usted', 'lo que tiene que hacer es depositar y enviar el comprobante de pago', 'entonces lo que hacen es hacer el deposito y rendirme el comprobante de pago', 'lo mismo el convenio de pago con el descuento para que usted le quede por escrito', 'le informo via whatsapp el dia de manana y usted me confirma la fecha de pago', 'como hector no pago en el area de cobranzas el banco lo dio de baja como cliente', 'pero igualmente por whatsapp usted va a tener la propuesta de pago']",
#        "['lo que estoy hecho de pago igualmente', 'eso lo tramita del banco en cuanto figura que ya se credito el pago']",
#        "['si lo que es los datos de pago ahora se les envia por whatsapp', 'y lo que es el libre deuda una vez que el pago ya este acreditado', 'home bank y no mercado pago se utiliza']",
#        "['me estoy comunicando cesar por el tema de la tarjeta visa que quedo pendiente de pago', 'mire le comento si consigue todo el dinero para hacerlo en un solo pago', 'y como tiene que hacer el deposito para que quede registrado pero necesitamos que confirme la fecha de pago', 'aja yo te confirmo la fecha de pago para la semana que viene']",
#        "['si es por el saldo pediente agonar el banco queria ofrecerle un descuento y un plan de pagos para que pagan sera el mismo']",
#        "['es por el pago que tenia que realizar', 'no mira no hice el pago porque yo tengo una tengo solicitado a la baja que hizo la tarjeta hace mucho tiempo atras', 'pago que ella iba a mandar un escrito y me iban a contestar en estos dias']",
#        "['cuando usted realiza el pago', 'lo va a hacer en un pago o en dos', 'no en un pago', 'ese pago', 'yo al pago', 'yo al pago le voy a informar que estoy la buena el viernes', 'que es en un pago si', 'y lo cancelan un pago con fecha']",
#        "['de igual forma el pago usted lo tiene que hacer en el banco']",
#        "['se comunique con nosotros a facilitarnos los datos de su pago', 'que seria el dia que pago la sucursal y el monto', 'en cualquier en cualquier de las sucursales le van a tomar el pago', 'ahi se acerca sin problemas le van a tomar el pago', 'puede acercarse y le van a tomar el pago', 'para que podamos registrar el pago senor', 'ahi llama por telefono entonces registramos el pago']",
#        "['si bueno nos estamos comunicando por esto es algo que le quedo pendiente para ver si hay posibilidades de llegar a un aporto de pagos', 'le quedaria en un pago de', 'y despues la ot quiere cancelar en un pago y no le paso el plan en cuotas', 'nosotros en realidad el pago usted lo hace nosotros intermediamos nada mas para la gestion de cobros si', 'el pago ahora cuando usted vea cuando yo vea que le pase los datos bueno va a asegurar obviamente los datos de nuestra agencia le vamos a emitir un recibo', 'y el banco ahi es que verifica que los datos que yo voy a pasar de lo que usted me pase que sea ya sea transferencia que pueda abonar por ventanilla tambien en la sucursal yo ahi se lo mando al banco el banco verifica que este todo ok y se imputa el pago si', 'todos los datos que le piden esto puede abonarlo en su cursal en cualquier su cursal le van a costantandar puede hacerlo por ventanilla unicamente este tipo de pago o puede abonarlo por transferencia si', 'ultima pregunta asi yo se esto lo elevo en sistema usted cuando estaria haciendo el pago']",
#        "['pesos estaban mis opciones de pago y ya lo', 'pesos esto puede usted pagarlo en un solo pago para hoy o manana ariel', 'no me usa el apago pero esta semana es imposible', 'si si la semana que viene se lo pago', 'perfecto y vas a realizar su pago por deposito o lo va a hacer por transferencia ariel tiene esas dos opciones', 'ya sea por compadre aqui mercado pago', 'perfecto nada mas porque si lo hace por mercado pago nosotros le enviamos el cvu directo del banco', 'asi no se remesa por el estudio y ingresa directo el pago no se si me explica', 'y no puede aunar el martes usted se comunica nuevamente por correo conmigo y yo le llamo de vuelta para agendar el proximo pago', 'le dejo el registro y le esperamos su pago entre lunes y martes de la semana que viene']",
#        "['silvia mas que nada la llamaba por el tema del pago que estaba acordado para el dia', 'o sea el viernes usted recien podra hacer el pago que esta mas liberada', 'entonces este viernes sin falta que se va a estar haciendo el pago mas que nada para', 'yo ya lo informo entonces silvia que el dia viernes usted hace el pago y me envia']",
#        "['pero lo vas a dar esta semana eduardo porque asi esto nos pasa todo y no lo pago por eso le conoci a todos', 'no lo pago todo esto', 'a usted lo pago todo']",
#        "['en un pago se le doy las opciones de cancelacion', 'le comienzo hablando sobre las quitas de cancelar en un pago', 'si en un pago cancelo', 'el banco le mantiene el mismo descuento en dos pagos de', 'hasta en tres pagos de', 'con unas formas de pago es que bueno', 'va al santander por ventanilla y yo lo hago un cupon de pago', 'una vez que me pago le saco una foto al ticket', 'recuerda que son pagos consecutivos y mensuales']",
#        "['referente al compromiso de pago', 'si la compromiso de pago hoy pero', 'aguardamos el pago para el dia lunes si']",
#        "['para poder confirmar el pago']",
#        "['y los planes de pago de mayo', 'pesos en un pago ya cancelaria el producto', 'con un cupon de pago', 'para hacer el pago']",
#        "['si queriamos recordarle para el dia de manana su pago de', 'perfecto una vez como le habiamos indicado ernesto una vez que haga el pago nos envia por fotos el comprobante para que podamos cargar al sistema']",
#        "['entonces para liquidar la deuda en dos pagos', 'seria el primer pago', 'si de pago contado no hay nada', 'para abonarlo en un pago', 'si son dos pagos o si es un pago', 'si yo por ejemplo te digo dos pagos', 'si puedo abonarlo en un pago']",
#        "['queriamos confirmar su pago para el dia de hoy', 'si usted tiene algun whatsapp yo le puedo enviar por whatsapp los datos del pago carlos', 'quiero matar todas las cuentas que tengo manana me sale un pago y quiero matar todos', 'le explico una vez que usted hace el pago nos envia la foto del comprobante por whatsapp para que podamos pasar los datos al banco', 'perfecto manana todo el pago en el banco no me ha tenido pago']",
#        "['de pago', 'es un comprobante de pago no son tickets son comprobantes de pago', 'pedimos sobre todo ya lo mucho encapie en que nos manden el comprobante el mismo dia que hacen el pago', 'yo te habia dicho hay otro sistema de pago donde vos no le depositas a nosotros', 'recibo de pago no te puedo hacer porque si no estariamos duplicando el comprobante', 'dos pagos el mismo dia tambien me importa', 'pagos de', 'bueno escuchame hacer pago antes de las']",
#        "['quiero que se admierga si lo tenes antes me lo mandas vos como hiciste los pagos por', 'pasado a cualquier hora me lo mandas yo me conecto lunes a las tres y ya levanto el pago', 'mandes el comprobante que yo lo lea y lo y lo se llama rendir o remesar al banco el pago']",
#        "['entiendo senor bueno entonces estaremos aguardando el comprobante de pago si']",
#        "['anteriormente nosotros hemos hablado con usted y le hemos enviado una propuesta de pago', 'en un pago de', 'esto bonando en un solo pago cancela queda libre de deuda y se bonifica la deuda con este monto', 'como ve la posibilidad de cancelarlo en un pago este mes', 'bueno entonces me mando esto y pago la mitad']",
#        "['queriamos confirmar su pago para el dia de hoy']",
#        "['pago por el banco santander']",
#        "['si senor alan le comunico del estudio juridico referiendo el compromiso de pago', 'perfecto senor alan entonces aguardamos el pago para el dia de hoy', 'a mas tardar que es el dia lunes es seguro el pago', 'le pase los datos por el whatsapp en este mismo numero que lo pago le podre', 'a volar por las sucursales o tambien lo puede realizar por home banking el pago', 'el pago']",
#        "['el encargado de los pagos es asi', 'y me indico que a mas tardar lo abona me dijo que no pudo realizar el pago y que lo', 'y luego luego de abonar el dia de manana que envie su comprobante de pago a ese numero']",
#        "['referente al compromiso de pago nada mas para saber si le estuvo llegando los datos a traves del whatsapp', 'ah perfecto senora cintia esta bien dejo asentado y aguardamos el pago para el viernes', 'bueno el primer pago bien muchas gracias hasta luego']",
#        "['la de fake pago de', 'iniciar los pagos en lo inmediato', 'se muece un intenso de pagos', 'recuerde cuando haga el pago parcial el', 'bien rap y pago eso no', 'rap y pago no', 'hacerle el favor quizas por mercado pago', 'cuando abona el pago parcial', 'lo acredito y ya le ingresa un pago', 'tiene que hacer el pago para que lo usted preocupe']",
#        "['yo necesito tot confirmar si va a pagar botemos fecha de pago el viernes', 'ok entonces bonifico la deuda al pago de', 'pesos para hacer efectivo el primer pago para el dia de lunes', 'tiene dos opciones de pago', 'pero tiene que hacer el pago por ventanilla y en efectivo', 'es que tiene que ser pago por ventanilla', 'el pago que usted va a hacer', 'que solamente va a cargar pago']",
#        "['referente al pago que tiene pendiente con nosotros']",
#        "['referente al compromiso de pago']",
#        "['queriamos agendar con usted una fecha de pago de ese saldo pendiente', 'tambien puedo hacerlo atras del mercado pago', 'bueno yo le mando todos los datos para que usted pueda realizar el pago']",
#        "['si referente al compromiso de pago que dejamos asentado nada mas de contacto', 'y aguardamos el primer pago para la fecha']",
#        "['a llegar a una seta exacta de pago si']",
#        "['y ahora le da molesto para recordarle el pago que hacemos para el dia de hoy', 'de todas maneras bueno yo ahora cuando recibo el pago cuando me pueda conectar al whatsapp']",
#        "['es referente al compromiso de pago que dejamos asentado para el dia viernes']",
#        "['solicito por favor que se comunique por el pago de su dedo al telefono']",
#        "['entiendes si pero yo porque yo tengo un que pago nada', 'bueno yo pido pago todo y le digo no no no no y ahora me voy a decir una deuda', 'me dice que llevo un que que me lo gara el pago entonces es muy peso', 'bueno entonces como va su plan de pago pero asi me parece hijoto pero igual porque', 'en este saldo no se puede hacer un plan de pago directamente se le pasa el numero de la', 'el miercoles seria la fecha limite de pago si', 'es un solo pago de', 'pero lo que usted tiene es un solo pago senor', 'es dos pagos o tres cuotas si', 'tiene un rapido pago y no se puede pagar', 'tiene un rapido pago y no se puede pagar', 'no en un rapido pago no tiene nada que ver porque esta una instancia prejudicial', 'entonces no tiene que ver un rapido pago a esta altura', 'tiene que hacerlo y una vez que realizan el pago en la cuenta recaudadora', 'el tema es ese del pago', 'esperenme cargando el pago']",
#        "['puede hacer es lo siguiente el primer pago tiene que estar en', 'horas el pago si', 'que hacer el pago de los', 'genial una vez que usted paga nosotros informamos que usted pago usted es asi tiene que apagar', 'el pago el dia', 'de pago si ahi le acabo de mandar si si ahi ya le cego si perfecto ahi', 'solicitando el pago perfecto']",
#        "['bueno lo que necesitaba era poder confirmar el acuerdo de pago usted me habia dicho', 'bueno el tema es que tanto la de un pago', 'lo que hice ayer es enviar una consulta a traves de mi supervisor al banco y nos dieron una prorroga de pago hasta el', 'cancele hoy ya en un pago', 'a un solo pago', 'cuando nosotros mandamos el primer pago', 'por falta de pago', 'y yo lo cargue el pago en el banco', 'con el pago la primera cuota', 'prorroga de plazo de pago al banco', 'por la voluntad del pago', 'pagos', 'el pago', 'directamente el pago', 'a ver dejame ver el pago', 'el pago', 'yo ya te lo desconteste pago a la de una vez', 'en el mismo dia que hace el pago', 'que despues cuando pago la cuota']",
#        "['asi que ahora y es yo que te mando el comprobante pago']",
#        "['pago para que pueda cancelar el mismo']",
#        "['nos estamos comunicando para ver si tienen condiciones de iniciar los pagos', 'mira a mi se me complica sobre el tema del pago de la cuenta no tengo problema en', 'como como lo de cuenta y pago quiero mas lo mas rapido posible para mi digo', 'primera opcion es que abone en un pago de', 'mayor o si usted quizas prefiere abonar de contado no se por ejemplo que le quede no se un pago', 'entre lunes martes le estoy pasando las instrucciones de pago y como le queda el monto definitivo', 'si es por lo del tema del pago eso ya le digo inclusive no hace falta que vaya usted', 'tenga la confirmacion le mando las instrucciones de pago para abonar por autoservice en su']",
#        "['con el de contados eso es un descuento de el treinta por ciento cancela el un pago de seis mil pesos', 'miren podemos pedir una extension de pago hasta el dia veinticuatro si darle dos semanas para que pueda arruir el dinero para cancelar con el salto del banco', 'bueno jose luis yo pido el descuento del banco para que cancelen entonces un pago de este mil pesos el vencimiento ultimo como les explicaba seria', 'para que usted deposite y envie el comprobante de pago', 'es un pago de seis mil pesos']",
#        "['y nosotros quisieramos conversar con ella para ver si podriamos llegar a un acuerdo de pago y ella les pueda cancelar', 'comprendo senor dependiendo si la senora quiere cancelar en un solo pago tenemos la opcion de hacerlo un descuanto', 'el primer pago antes de las', 'pago antes de las cuarenta y', 'el tres pago en tres paus', 'cuatro mil y le pago dos de', 'pagos de dos mil cuatrocientos']",
#        "['me puede mandar por whatsapp un lin de pago y oir a bono']",
#        "['pesos queriamos confirmar su pago para el dia de hoy']",
#        "['leer bien entonces el lunes o martes hace el pago nelson']",
#        "['si lo unico que le pido es que una vez que haga el pago', 'para que podamos cargar el pago senor']",
#        "['por favor damos su pago senor joaquin']",
#        "['ahora mismo le envio el whatsapp a ese numero patricia y esperamos un pago del dia de']",
#        "['pago', 'yo en mi mercado pago no puedo pagar porque no tengo este plata en mi cuenta de mercado', 'pago', 'vos me tendrias que mandar un link de pago', 'yo entro al link y lo pago desde mercado pago con una tarjeta de debito credito', 'si no en un rapipago puede ser o en un pago facil', 'en un rapipago puede intentar pero tambien ahora o sea desde ayer empezaron a pedirnos', 'entonces para entonces para te puedo pagar o con transferencia o con mercado pago', 'dejame ver si yo puedo pagar desde las tarjetas que tengo en el mercado pago vueltas viste', 'lo pago sin falta el tema es que bueno no se si se puede', 'vale entonces yo te prometo que ese dia lo pago te lo transfero', 'mi novio trabaja en negro tiene tarjetas de credito pero no puedo pagar con eso en el mercado pago', 'paga todo por ese mercado pago mercado libre porque no tiene el token no puede sacar plata']",
#        "['una ultima consulta el pago lo puede realizar el viernes a', 'para que fecha le queda mejor porque tengo que dejar registro la fecha de pago']",
#        "['no porque yo quiero abonar aunque sea en algun repipago en algun lugar donde pueda abonar', 'como le comento el rapipago tiene un problema', 'no quiero que abone por repipago', 'pago']",
#        "['no se si ya pudisteis hacer el pago', 'ah pero no pudo juntar nada como para hacer un pago parcial y mantener el mismo acuerdo', 'o sea usted o sea para mantenerle el acuerdo yo le puedo tomar un pago parcial de la cuota', 'usted podra hacer el pago']",
#        "['nosotros para que podamos confirmar el pago convenido para el dia de ayer']",
#        "['despues vos conoces el pago y nos envias el comprobante', 'en un pago']",
#        "['lo que le pido a la senora oriana es que nos envie la foto del comprobante una vez que haga el pago para que podamos cargar el sistema si']",
#        "['bueno julio ahora cuando ingreses le pongo el mando de lo que he recibido y bueno el proximo pago recien al mes que viene si', 'bueno si llegamos al proximo pago']",
#        "['hacer un acuerdo de pago con usted para poder cancelar ese saldo si lo que le puedo ofrecer', 'hacemos si lo que necesitaria es que usted me agende una fecha para el primer pago que', 'mantener el plan de pagos el financiamiento de los seis pagos dale dale si me menciona su correo', 'le digo que han dado los seis pagos primer pago el diez hasta el diez de junio lo esperamos']",
#        "['que suerte me alegro te queria consultar luis usted pudo realizar el pago hasta', 'el momento no pudo realizar el pago', 'el whatsapp te enviaron un dato de romeo yo le voy a pasar el pago al whatsapp cual', 'y se quedaba con ese plan de pagos porque yo le habia hecho otro plan de pagos con menores', 'y le paso nuevamente los datos con el pago de']",
#        "['me iba a brindar un plan de pago', 'o pagarlo por whatsapp y pago', 'pago de', 'quien es con banking mercado pago']",
#        "['un mensaje que se comunique para informar el pago']",
#        "['no le digamos tengamos tu ticket digamos bueno este pago que les ingreso aplicarlo', 'si si si si puedes hacer en los pagos si si si', 'todos los pagos que hagas hacerlo a la cuenta que te acabo de pasar hacerlo bien y mandame']",
#        "['pago necesitamos enviarle sus datos para que pueda realizarlo por ventanilla', 've que no hay nada asentado como para que usted realice el pago me entiende walter', 'si no hay problema yo lo agendo en el sistema para que el viernes proximo usted pueda realizar el pago', 'bien le envio entonces sus datos para que pueda realizar el pago por ventanilla y lo dejamos asentado para el proximo viernes']",
#        "['el primer pago cuando lo hace elizabeth', 'bien pero esto donde lo pago tengo que ir al banco', 'se dirija al banco con los datos que yo les facilite hace el pago', 'para que podamos cargar el pago elizabeth', 'y con esos datos usted va a poder hacer el pago']",
# ...
#        "['cuanto me quedaba en un pago se acuerda claro espero que busque cuando hablamos saber que yo', 'con los gastos y todo ah en un pago claro son casi']",
#        "['donde pago', 'ultimo pago en tarjeta de credito', 'por autoservicio pago', 'habiamos quedado en el plan de pago', 'si lo hacen un pago', 'lo hago en un pago', 'en un solo pago', 'para que lo pueda organizar el pago', 'le comento como es el pago', 'el pago lo hace por el auto servicio', 'lo puede realizar tambien por mercado pago', 'en este caso pago por transferencia', 'yo a la manana lo hago el pago', 'para que abone tranquila y pueda registrar el pago', 'nosotros le pasamos los datos para que usted pueda gestionar el pago', 'por el banco mercado pago', 'que podria ser enviado en cuanto a pago', 'cuando tiene el ticket de pago de aca hasta dia']",
#        "['que esto lo pueda abonar en un solo pago cancelatorio', 'o se le puede armar un plan de pago de tres cuotas', 'luciana no quiero lo voy a hacer en un solo pago para manana', 'le voy a estar enviando a los anties del pago', 'en un pago facil', 'se le va a estar enviando a los datos del pago los datos en numero de la cuenta para que', 'si si esta que envie los datos del pago para que lo pueda realizar si', 'para que esto asi cargamos ese datos del pago y informamos al banco que se ha cancelado', 'no hay pago facil o rapid pago a nombre con el dni de federico no']",
#        "['el tenia un compromiso de pago y no lo abono', 'pero bueno como no me contestan no se que lo que va a decir si hay algun interes de pago']",
#        "['una vez que lo guia la foto nosotros lo cargamos de manera manual y dejamos asentado que usted pago', 'asi pago ya le da el de baja a todos directamente']",
#        "['ah por favor negocian la deuda en dos pagos sin quita o en un pago con la quita', 'por lo que estaba viendo si no tienen autorizado ellos hacer con quita en pago', 'te dijeron en dos pagos te pueden ofrecerla o con quita en un pago al contado', 'ahora por lo que veo te van a ofrecer quita si vas a hacer un solo pago', 'o sin quita pero en dos pagos mensuales']",
#        "['pago yo vive en mi app tengo una parte que hice pago realizado seria esta la transferencia', 'toda la vida con el hecho pago']",
#        "['si si estamos tratando ahi de completar el pago ese y ya esta']",
#        "['tienen otras opciones de pago porque eso era como una cancelacion', 'si si tienes afecto porque ahora no ingreso ningun pago aparte durante este', 'o sea lo puedo pagar en el pago es facil rapido todo tiene que ser en el banco', 'le dice le recuerdo que tiene un compromiso de pago paraliga y le pone deposito bancario banco bbva', 'antes de yo poner te lo puedo transferir del mercado pago ahi', 'via whatsapp tiene que enviar cada ticket de pago']",
#        "['sin cubrir el pago minimo', 'ver las posibilidades de pago', 'vemos las opciones de pago si', 'cuotas estamos hablando de tres pagos de', 'le va a solicitar el pago de un anticipo del', 'pago de practicamente', 'lo hacemos con los pagos entonces', 'si por favor pero en este caso que puedo hacer con la tarjeta la pago y ya la pago', 'le hago una consulta senora posibilidad de hacer el primer pago el dia lunes que', 'con el tema del pago no se si para el resto de los meses podemos acentarlo para los dias', 'usted lo puede adelantar los pagos si', 'le voy a pasar por whatsapp si le parece bien los datos para realizar los pagos']",
#        "['y le quedaria en un pago de', 'la otra opcion es un plan de pago con un descuento un poco menor es decir obviamente', 'pagos todos juntos se descuenta', 'lo que quiero decir es que si bien los pagos se descuentan tiene que tener en cuenta que', 'esta bien no no no ustedes por los pagos que eso tranquilo que usted siempre que', 'envie el comprobante y el pago se impute en ese momento y se ha quedado descontado', 'lo que es la propuesta de pago', 'en que nosotros imputamos el pago y se descuenta si asi que ese seria el punto mas importante', 'margen y no quede tan justo con el plazo de pago', 'bueno usted yo ahora le envio toda la informacion de pago los numeros de cuenta cual es el']",
#        "['si bueno ya me avisa y visa bueno avisa del pago si', 'pues como que esta el pago hecho a la cuenta es como que la cuenta es el banco no es de visa', 'hay un pago el doce del cinco puede ser que todavia no este descontado', 'hay un pago de nueve mil pesos el doce del cinco', 'se debe haber acreditado recuerde que siempre que la tarjeta se da de baja y usted hace un pago directo a la tarjeta', 'si el doce de mayo fue o sea que el pago esta acreditado lo que me mandan a mi es la diferencia', 'y con honorarios incluidos tendria que abonar un pago de', 'y vemos a ver si yo lo puedo ayudar aunque sea si pueda hacer un pago parcial', 'la idea es que en la medida que haya un pago', 'yo digo a donde yo trabajo este no me pago todavia por cajero', 'y se volvio a la flecha me sacaron la montilla y me hizo a donde me pago', 'porque por los pagos que se vienen haciendo', 'un parcial un pago algo']",
#        "['es por el pago que se tiene pendiente con fecha', 'claro porque la cuenta de ella esta inhabilitada entonces los pagos las transferencias no le entran a la tarjeta']",
#        "['el pago senor', 'voy a seguir el pago pero el compromiso mio de pagar esta pero que me lo hagan en como', 'en el caso de que lo abone en un solo pago entre', 'ya que no lo va a poder hacer en un pago igual le hacemos un descuento pero', 'para mi me gustaria un pago no tengo ningun drama pero el tema es que no puedo conseguir', 'y tendria que ser el primer pago antes de la quincena fernando', 'si si si me dame los comprantes y pago por medio de la pipa no se como', 'perfecto y ahi nada mas acerquese para hacer el pago lo que yo le pediria a usted', 'nosotros somos del estudio juridico mopc de igual forma usted el pago lo va a hacer', 'pago el', 'podamos cargar el pago en el sistema fernando']",
#        "['a ver usted me manda un comprobante de pago', 'veo que me mando el comprobante de pago']",
#        "['habiamos dialogado al respecto de un convenio al pago en el mes', 'le comento al hija de la fecha el banco esta lanzando una propuesta de pago para una cancelacion', 'que posibilidades de pago tiene dentro de lo que es el mes de junio si']",
#        "['bien el dia de hoy sin falta vamos a tener que recibir la foto del comprobante del pago aunque sea de una transidencia bancaria']",
#        "['le tendria que informar el medio de pago por whatsapp no se si quiere que le', 'de que es del banco pero yo lo unico que necesito es confirmar una fecha de pago', 'usted me dice una fecha de pago yo solamente le informo al banco', 'para que recuerde verifique con el banco antes de efectuar el pago']",
#        "['pago en el cual no pudo cumplir si si barbaro al dia en la fecha nos contactamos', 'da un plazo para poder cerrar un acuerdo de pago si en el cual se puede cumplir', 'unico pago por', 'todo en un unico pago estaria dentro de sus posibilidades o sigue mismo no teniendo']",
#        "['veronica bueno tengo segun lo que me figura aca para que realices el ultimo pago']",
#        "['y tiene que hacer el pago ya sea por cajero o autoservicio o puede hacerlo a traves de una transferencia bancaria si', 'esto se puede hacer en un pago porque ya directamente es un saldo menor para hacer una instancia prejuicial si lo que si el pago lo tendria que hacer en el transcurso de esta semana si', 'asi que ha sentado y ya podemos congelar la deuda cuando ingresa el pago esta directamente se cancela si', 'un pago de', 'cuando se realice el pago por el cajero autoservicio si', 'cuando se realice el pago le va a tirar un ticket si']",
#        "['alvariz o con la encargada de los pagos de ella si con ella habla', 'es cuando ingresan los pagos esta bien usted se compromete a aboner el', 'esta al pago no puedo mantenerle el plan no no no sea el problema']",
#        "['si habiamos acordado nosotros un plan de pago o convencimiento para el dia de hoy', 'si correcto usted pudo realizar el pago']",
#        "['si asi que ya despues te voy a estar llamando a ver como que pago puedo hacer por el tuyo', 'o sea que en el prendadio no lo harias como acordamos en un pago', 'si si si le voy a hacer en un pago a todos lo tengo que hacer en un pago', 'no no con ellos no me da una opcion de pago', 'yo le dije lo que vos me hiciste que el gedco no te da opciones de pago solo al contacto no se si esto va a ayudar a mi a cobrarte deuda y a vos a tener una facilidad con ellos', 'el gerente general en caso central dice decirle que hago un plan de pago y no perdemos un cliente pero le chico un huevo me entendes', 'nosotros en algunos casos podemos dar hasta seis pagos', 'esta bien pero ya esta ya vamos a hacer un pago', 'y me queda nada distinto de hecho lo que hay que pagar en el banco con un solo pago que es la otra deuda', 'el malo es que yo te pedi para cancelarlo lo tengo autorizado lo que necesito es que me liberen el canal de pago', 'te lo van a tomar como pago parcial de la deuda total']",
#        "['camila le habla a medero noventa del estudio fm la llamo por el pago querias saber si', 'comprometi a hacer el pago vine el viernes el sabado y el domingo por supuesto que no pude salir porque', 'comprendo bueno en ese caso si le voy a pedir que bueno por excepcion haga el pago', 'por favor envienos el pago ahi y basicamente envienos el comprobante si']",
#        "['bueno no se si pudo hacer el pago', 'se ha estado de baja por el acardanza digamos de los pagos', 'es el pago que usted realizo', 'no recuerdo como hacia los pagos', 'el pago se realice directamente', 'para que pueda hacer el pago', 'si cosa de que el pago', 'asi directamente el pago entra al banco', 'y el pago de la cuenta seria']",
#        "['con eso yo rindo el pago']",
#        "['en caso de que hoy no puedas hacer el pago', 'y la realidad es que si no pago va a terminar en una instancia legal que bueno que ninguno quiere', 'por que te pregunto esto porque si hoy me contestes me escribis diciendo que hoy no puedes hacer el pago', 'seria hoy o manana que te podemos recibir el pago decirte bien', 'hasta despues poder abordar el plan de pago asi como me decis me saluda y me sirve', 'para ahora estas tomando tu tiempo fijate si puedes hacer el pago de', 'no hay nada que se pueda hacer un poco mas amplio pero que el pago mensual te menos', 'meses extra de pago de', 'que yo pago de', 'y yo pago de', 'y yo pago de', 'y yo pago de', 'y yo pago de', 'y yo pago de', 'mas que mensaje lo que necesito que me mande es el pago', 'de manana no me mandaste el pago de']",
#        "['ahora si disculpe apago', 'nosotros ahora dejamos el pago para el', 'solo este mes ya vamos a realizaria dos pagos', 'o bueno mas si usted necesita realizar mas pagos', 'abona directamente los tres mil cincuenta en un pago si', 'como seria la forma de pago', 'lo que es el pago en si lo puede realizar', 'sino si tiene marcado pago por ejemplo home banking', 'lo pago como puedo', 'y le envio los datos de pago entre hoy y manana', 'bien y pues yo ya pago todo el mundo tal']",
#        "['todo bien te llamaba para ver si se apuesta a hacer el pago para ir rindiendolo al banco', 'lo pago y', 'bueno diego emiliano acuerdate de mandarnos el comprobante asi podemos procesar el pago']",
#        "['y enviar el comprobar del pago a este whatsapp recuerda que no es julio experiado asi que']",
#        "['yo doy de alta el compromiso con la fecha de pago el dia de viernes', 'es el medio de pago nada mas', 'pero hay gente que tiene muy lejos la suposal y hasta con cuentas que abren el mercado pago', 'hay muchas hay muchas bocas de pago que se abrieron por esta cuestion de la pandemia', 'si hay una transferencia de pago de provincia a la cuenta de la situacion', 'igualmente el pago', 'si usted ya le da perdon disculpame ya entonces le da el alta ahora que pago el viernes']",
#        "['bien usted podria cancelar en un pago gustavo', 'si me lo hace en dos pagos que pago manana mismo', 'en dos pagos', 'eras un lindel pago y ya estoy normal', 'claro no entonces abonaria en un pago dentro de este mes digamos', 'del pago total de la deuda', 'yo pago esto', 'apenas usted abone se verifique el pago', 'comprobante del pago por whatsapp']",
#        "['como conseguiria tu clasico de pago y', 'es que todos los meses me estan robando es una gran barbada el pago es de nueve mil', 'bueno yo cuando pago esto automaticamente me comunico al estudio', 'para el pago']",
#        "['nada confirma con usted si quiere hacer un plan de pago', 'yo le usted quiere hacer la cancelacion en un pago o lo quiere hacer en dos cuotas', 'y en dos si para eso bien y usted la fecha de pago a mas', 'de pago con el vencimiento la dos cuotas le va a vencer a masterlar short lo dejo']",
#        "['va a estar en la parte de abajo en los datos de pago', 'por hacer un solo pago no', 'por eso ahi no figura el plan de pagos', 'yo ahi te modifique los datos de la parte de pago']",
#        "['lo que sucedio con el pago', 'yo ya le mande igualmente las formas de pago pero nunca me envio el pago', 'no no no no pero escucheme yo lo pago hoy o manana a la manana lo pago por pago', 'pedido la exercion de que pague por rapipago recuerda le pase para que pague por rapipago', 'nada mas rapipago tiene que ser si o si rapipago', 'claro porque yo no tengo rapipago aca lo tengo alla en libertad', 'a ver tiene mi numero por whatsapp yo le pase las formas de pago igualmente si', 'enviar de comprobante de pago y yo le mando tambien en la pagina web del estudio si', 'que haga transferencia o como hago o lo de rapipago', 'para rapipago para rapipago eh', 'ah rapipago por rapipago a pagar', 'o pago facil no se', 'pago facil no se puede', 'pago facil no se puede solo rapipago o transferencia', 'bueno entonces mandeme con rap y pago']",
#        "['que estaba con un plan de pagos', 'generalmente igual cuando pasa el tiempo se descuenta obviamente el pago', 'lo que puedo ver ahora en el bajo no puedo ver esos pagos', 'yo no se si esos intereses cubrieron lo que pago', 'como no se completa el plan de pagos', 'mas alla que se descuenta el pago no']",
#        "['para hacer el pago de la primera cuota de']",
#        "['entonces bueno lo dejo el compromiso de pago del', 'por favor envie el pago asi ya la reconoce en la quita si']",
#        "['si lo hago en un pago seria el mismo monto']",
#        "['si el me pidio que me comunicara con ustedes para armar algun plan de pago', 'porque el tenia que pagar en el mes de mayo se le hizo un acuerdo de pago', 'pagos de', 'o el que quieran enviar con el pago', 'le toman el pago le dan un ticket se piquenle', 'dias del pago', 'ah despues del ultimo pago']",
#        "['del banco frances la hablamos por un pago que tenia vencimiento en el dia de la fecha', 'adelante digamos el pago']",
#        "['senora para ofrecerle un acuerdo de pagos en este caso', 'en un solo pago', 'le quedan un solo pago de', 'pesos en un solo pago', 'no no hay chance de que lo hagan en un solo pago', 'y no puede dar buen acres solo un solo pago', 'y los maximos que se pueden hacer son dos pago', 'si en dos pago con cancelacion', 'le comento como lo hace el pago', 'el pago lo hace por el cajero', 'pago por transferencia desde cualquier otro banco', 'como ha marcado pago', 'en el caso de que este pereo con mercado pago', 'si pero con mercado pago', 'que le puedo pagar con mercado pago', 'lo que necesito es confirmar la fecha de pago', 'la fecha de pago necesito confirmar al lunes a mas tardar']",
#        "['con comprobante de pago', 'perfecto bueno aguardamos el pago para ese dia entonces david']",
#        "['despues bueno veremos de aca a fin de mes y pago otro porcentaje mas', 'mirad me pago el cliente dejamelo es como nada', 'si por lo menos hago un pago parcial', 'despues vemos que el plan de pago le toma al banco', 'se me pago todo listo porque esto para mi']"],
#       dtype=object)
